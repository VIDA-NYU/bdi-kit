# %% [markdown]
# # Getting Started

# %% [markdown]
# First, import the class `APIManager`.

# %%
from bdikit import APIManager

# %% [markdown]
# ## Dataset Loading

# %% [markdown]
# In this example, we are mapping data from Dou et al. (https://pubmed.ncbi.nlm.nih.gov/37567170/) to the GDC format.

# %%
manager = APIManager()

# %%
dataset_path =  './datasets/dou.csv'
dataset = manager.load_dataset(dataset_path)
dataset
# Out:
#            Country Histologic_Grade_FIGO Histologic_type  \
# 0    United States          FIGO grade 1    Endometrioid
# 1    United States          FIGO grade 1    Endometrioid
# 2    United States          FIGO grade 2    Endometrioid
# 3              NaN                   NaN  Carcinosarcoma
# 4    United States          FIGO grade 2    Endometrioid
# ..             ...                   ...             ...
# 99         Ukraine          FIGO grade 3    Endometrioid
# 100        Ukraine          FIGO grade 2    Endometrioid
# 101  United States                   NaN          Serous
# 102        Ukraine                   NaN          Serous
# 103        Ukraine                   NaN          Serous
#
#     Path_Stage_Primary_Tumor-pT Path_Stage_Reg_Lymph_Nodes-pN  \
# 0                pT1a (FIGO IA)                           pN0
# 1                pT1a (FIGO IA)                           pNX
# 2                pT1a (FIGO IA)                           pN0
# 3                           NaN                           NaN
# 4                pT1a (FIGO IA)                           pNX
# ..                          ...                           ...
# 99               pT1a (FIGO IA)                           pNX
# 100               pT2 (FIGO II)                           pN0
# 101               pT2 (FIGO II)                           pN0
# 102              pT1a (FIGO IA)                           pN0
# 103                         NaN                           NaN
#
#     Clin_Stage_Dist_Mets-cM                       Path_Stage_Dist_Mets-pM  \
# 0                       cM0                            Staging Incomplete
# 1                       cM0                            Staging Incomplete
# 2                       cM0                            Staging Incomplete
# 3                       NaN                                           NaN
# 4                       cM0  No pathologic evidence of distant metastasis
# ..                      ...                                           ...
# 99                      cM0                            Staging Incomplete
# 100                     cM0                            Staging Incomplete
# 101      Staging Incomplete                            Staging Incomplete
# 102                     cM0                            Staging Incomplete
# 103                     NaN                                           NaN
#
#     tumor_Stage-Pathological FIGO_stage    BMI   Age  \
# 0                    Stage I         IA  38.88  64.0
# 1                   Stage IV         IA  39.76  58.0
# 2                    Stage I         IA  51.19  50.0
# 3                        NaN        NaN    NaN   NaN
# 4                    Stage I         IA  32.69  75.0
# ..                       ...        ...    ...   ...
# 99                   Stage I         IA  29.40  75.0
# 100                 Stage II         II  35.42  74.0
# 101                 Stage II         II  24.32  85.0
# 102                  Stage I         IA  34.06  70.0
# 103                      NaN        NaN    NaN   NaN
#
#                           Race               Ethnicity  Gender  \
# 0                        White  Not-Hispanic or Latino  Female
# 1                        White  Not-Hispanic or Latino  Female
# 2                        White  Not-Hispanic or Latino  Female
# 3                          NaN                     NaN     NaN
# 4                        White  Not-Hispanic or Latino  Female
# ..                         ...                     ...     ...
# 99                         NaN                     NaN  Female
# 100                        NaN                     NaN  Female
# 101  Black or African American  Not-Hispanic or Latino  Female
# 102                        NaN                     NaN  Female
# 103                        NaN                     NaN     NaN
#
#                 Tumor_Site Tumor_Focality  Tumor_Size_cm
# 0     Anterior endometrium       Unifocal            2.9
# 1    Posterior endometrium       Unifocal            3.5
# 2           Other, specify       Unifocal            4.5
# 3                      NaN            NaN            NaN
# 4           Other, specify       Unifocal            3.5
# ..                     ...            ...            ...
# 99          Other, specify       Unifocal            4.2
# 100         Other, specify       Unifocal            1.5
# 101         Other, specify       Unifocal            3.8
# 102         Other, specify       Unifocal            5.0
# 103                    NaN            NaN            NaN
#
# [104 rows x 17 columns]

# %% [markdown]
# ## Reducing the GDC Scope

# %% [markdown]
# Since the GDC contains 700+ attributes, a first step we take is to select a subset of those attributes that are likely matches to the attributes in the Dou et al. schema -- the top-k candidates for each column. We can explore the candidates for each column using the ScopeReducerExplorer.

# %%
manager.reduce_scope()
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|                                                                                                                                                                                                                | 0/17 [00:00<?, ?it/s]We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 16.54it/s]
# Table features extracted from 17 columns
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 734/734 [01:20<00:00,  9.14it/s]
# Table features extracted from 734 columns
# Column(styles={'background': 'white'})
#     [0] Row(align=('start', 'center'))
#         [0] Markdown(str)
#         [1] Spacer(width=30)
#         [2] Select(align='center', name='Column selected', options=['Country', 'Histologic_Gr...], value='Country')
#         [3] Spacer(width=30)
#         [4] EditableIntSlider(align='center', end=20, name='Number of candidates', start=1, value=5, width=300)
#     [1] Spacer(height=30)
#     [2] Row
#         [0] Column(width=500)
#             [0] ParamFunction(function, _pane=Vega, defer_load=False)
#         [1] Spacer(width=30)
#         [2] ParamFunction(function, _pane=Tabulator, defer_load=False)

# %% [markdown]
# ## Column Mapping

# %% [markdown]
# Perform column mapping. By default it uses [similarity flooding algorithm](https://ieeexplore.ieee.org/document/994702).

# %%
column_mappings = manager.map_columns()
# Out:
#                   Original Column                Target Column
# 0                         Country             country_of_birth
# 1           Histologic_Grade_FIGO  histologic_progression_type
# 2                 Histologic_type               dysplasia_type
# 3     Path_Stage_Primary_Tumor-pT              uicc_clinical_m
# 4   Path_Stage_Reg_Lymph_Nodes-pN         ishak_fibrosis_score
# 5         Clin_Stage_Dist_Mets-cM                   inrg_stage
# 6         Path_Stage_Dist_Mets-pM    last_known_disease_status
# 7        tumor_Stage-Pathological         tumor_grade_category
# 8                      FIGO_stage                   figo_stage
# 9                             BMI                 age_at_index
# 10                            Age                       weight
# 11                           Race                         race
# 12                      Ethnicity                    ethnicity
# 13                         Gender                       gender
# 14                     Tumor_Site                  tumor_shape
# 15                 Tumor_Focality               tumor_focality
# 16                  Tumor_Size_cm                  tumor_depth

# %% [markdown]
# Users can change the algorithm to perform the column mappings. We provide a GPT-based algorithm (`GPTAlgorithm`). To use it, you need to add an environment variable for your OpenAI key (`export OPENAI_API_KEY='your-api-key-here'`)

# %%
column_mappings = manager.map_columns(algorithm='GPTAlgorithm')
# Out:
#                   Original Column                     Target Column
# 0                         Country                  country_of_birth
# 1           Histologic_Grade_FIGO                       tumor_grade
# 2                 Histologic_type                 primary_diagnosis
# 3     Path_Stage_Primary_Tumor-pT                        figo_stage
# 4   Path_Stage_Reg_Lymph_Nodes-pN             ajcc_pathologic_stage
# 5         Clin_Stage_Dist_Mets-cM                   ajcc_clinical_m
# 6         Path_Stage_Dist_Mets-pM             ajcc_pathologic_stage
# 7        tumor_Stage-Pathological             ajcc_pathologic_stage
# 8                             BMI                               bmi
# 9                             Age                  age_at_diagnosis
# 10                           Race                              race
# 11                      Ethnicity                         ethnicity
# 12                         Gender                      demographics
# 13                     Tumor_Site                      primary_site
# 14                 Tumor_Focality                    tumor_focality
# 15                  Tumor_Size_cm  tumor_largest_dimension_diameter

# %% [markdown]
# Users can update column mappings through the `update_column_mappings` method.

# %%
manager.update_column_mappings([('Country', 'country_of_residence_at_enrollment'), ('Path_Stage_Primary_Tumor-pT', 'ajcc_pathologic_t'), ('Path_Stage_Reg_Lymph_Nodes-pN', 'ajcc_pathologic_n'), ('Path_Stage_Dist_Mets-pM', 'ajcc_pathologic_m'), ('Gender', 'gender'), ('Tumor_Site', 'tissue_or_organ_of_origin')])
# Out:
# Column mapping updated!
#                   Original Column                       Target Column
# 0                         Country  country_of_residence_at_enrollment
# 1           Histologic_Grade_FIGO                         tumor_grade
# 2                 Histologic_type                   primary_diagnosis
# 3     Path_Stage_Primary_Tumor-pT                   ajcc_pathologic_t
# 4   Path_Stage_Reg_Lymph_Nodes-pN                   ajcc_pathologic_n
# 5         Clin_Stage_Dist_Mets-cM                     ajcc_clinical_m
# 6         Path_Stage_Dist_Mets-pM                   ajcc_pathologic_m
# 7        tumor_Stage-Pathological               ajcc_pathologic_stage
# 8                             BMI                                 bmi
# 9                             Age                    age_at_diagnosis
# 10                           Race                                race
# 11                      Ethnicity                           ethnicity
# 12                         Gender                              gender
# 13                     Tumor_Site           tissue_or_organ_of_origin
# 14                 Tumor_Focality                      tumor_focality
# 15                  Tumor_Size_cm    tumor_largest_dimension_diameter

# %% [markdown]
# ## Value Mapping

# %% [markdown]
# Perform value mapping. By default it uses the edit distance algorithm. In this example it will use and LLM-based algorithm.

# %%
value_mappings = manager.map_values('LLMAlgorithm')
# Out:
# Column Histologic_Grade_FIGO:
#   Current Value Target Value  Similarity
# 0  FIGO grade 1           G1         1.0
# 1  FIGO grade 2           G2         1.0
# 2           nan      Unknown         1.0
# 3  FIGO grade 3           G3         1.0
# Column Histologic_type:
#     Current Value                      Target Value  Similarity
# 0    Endometrioid  Endometrioid adenocarcinoma, NOS         1.0
# 1  Carcinosarcoma               Carcinosarcoma, NOS         1.0
# 2          Serous        Serous adenocarcinoma, NOS         1.0
# 3      Clear cell              Clear cell carcinoma         1.0
# Column Path_Stage_Primary_Tumor-pT:
#       Current Value Target Value  Similarity
# 0    pT1a (FIGO IA)          T1a         1.0
# 1               nan      Unknown         1.0
# 2  pT3a (FIGO IIIA)          T3a         1.0
# 3      pT1 (FIGO I)           T1         1.0
# 4    pT1b (FIGO IB)          T1b         1.0
# 5     pT2 (FIGO II)           T2         1.0
# 6  pT3b (FIGO IIIB)          T3b         1.0
# Column Path_Stage_Reg_Lymph_Nodes-pN:
#       Current Value Target Value  Similarity
# 0               pN0           N0         1.0
# 1               pNX           NX         1.0
# 2               nan      Unknown         1.0
# 3  pN2 (FIGO IIIC2)           N2         1.0
# 4  pN1 (FIGO IIIC1)           N1         1.0
# Column Clin_Stage_Dist_Mets-cM:
#         Current Value Target Value  Similarity
# 0                 cM0           M0         0.9
# 1                 nan      Unknown         1.0
# 2  Staging Incomplete      Unknown         0.9
# 3                 cM1           M1         0.9
# Column Path_Stage_Dist_Mets-pM:
#                                   Current Value Target Value  Similarity
# 0                            Staging Incomplete      Unknown         1.0
# 1                                           nan      Unknown         1.0
# 2  No pathologic evidence of distant metastasis           M0         1.0
# 3                                           pM1           M1         1.0
# Column tumor_Stage-Pathological:
#   Current Value Target Value  Similarity
# 0       Stage I      Stage I         1.0
# 1      Stage IV     Stage IV         1.0
# 2           nan      Unknown         1.0
# 3     Stage III    Stage III         1.0
# 4      Stage II     Stage II         1.0
# Column Race:
#                Current Value               Target Value  Similarity
# 0                      White                      white         1.0
# 1                        nan               not reported         1.0
# 2                      Asian                      asian         1.0
# 3               Not Reported               not reported         1.0
# 4  Black or African American  black or african american         1.0
# Column Gender:
#   Current Value Target Value  Similarity
# 0        Female       female         1.0
# 1           nan      unknown         1.0
# Column Tumor_Site:
#            Current Value Target Value  Similarity
# 0   Anterior endometrium  Endometrium         1.0
# 1  Posterior endometrium  Endometrium         0.9
# 2         Other, specify      Unknown         1.0
# 3                    nan      Unknown         1.0
# Column Tumor_Focality:
#   Current Value Target Value  Similarity
# 0      Unifocal     Unifocal         1.0
# 1           nan      Unknown         1.0
# 2    Multifocal   Multifocal         1.0
# Column Country:
#    Current Value    Target Value Similarity
# 0  United States   United States        1.0
# 1        Ukraine         Ukraine        1.0
# 2         Poland          Poland        1.0
# 3            nan  [No match found]          -
# 4  Other_specify  [No match found]          -
# Column Ethnicity:
#             Current Value            Target Value Similarity
# 0  Not-Hispanic or Latino  not hispanic or latino        1.0
# 1      Hispanic or Latino      hispanic or latino        1.0
# 2            Not reported          [No match found]          -
# 3                     nan          [No match found]          -
