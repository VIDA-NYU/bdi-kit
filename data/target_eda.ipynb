# %%
import pandas as pd
import os
import numpy as np


df_target = pd.read_csv('target.csv')
df_target
# Out:
#      case_submitter_id  age_at_diagnosis                       race  \
# 0              01BR001           20089.0  black or african american
# 1              01BR008           17532.0  black or african american
# 2              01BR009           23376.0  black or african american
# 3              01BR010           23741.0  black or african american
# 4              01BR015           12784.0                      white
# ...                ...               ...                        ...
# 1063         C3N-01520           25202.0               Not Reported
# 1064         C3N-01521           27394.0               Not Reported
# 1065         C3N-01537           27028.0               Not Reported
# 1066         C3N-01802           31046.0  black or african american
# 1067         C3N-01825           25568.0               Not Reported
#
#                    ethnicity  gender  vital_status ajcc_pathologic_t  \
# 0     not hispanic or latino  female         Alive                T2
# 1     not hispanic or latino  female  Not Reported      Not Reported
# 2     not hispanic or latino  female  Not Reported      Not Reported
# 3     not hispanic or latino  female  Not Reported      Not Reported
# 4     not hispanic or latino  female         Alive                T2
# ...                      ...     ...           ...               ...
# 1063            Not Reported  female          Dead               T1a
# 1064            Not Reported  female         Alive               T1a
# 1065            Not Reported  female         Alive                T2
# 1066  not hispanic or latino  female         Alive                T2
# 1067            Not Reported  female         Alive               T1a
#
#      ajcc_pathologic_n ajcc_pathologic_stage tumor_grade tumor_focality  \
# 0                  N1c              Stage II          GX   Not Reported
# 1         Not Reported          Not Reported          GX   Not Reported
# 2         Not Reported          Not Reported          GX   Not Reported
# 3         Not Reported          Not Reported          GX   Not Reported
# 4                   N1              Stage II          GX   Not Reported
# ...                ...                   ...         ...            ...
# 1063                NX               Stage I          G2     Multifocal
# 1064                NX               Stage I          G3       Unifocal
# 1065                N0              Stage II          G3       Unifocal
# 1066                N0              Stage II          G3       Unifocal
# 1067                N0               Stage I          G3       Unifocal
#
#      tumor_largest_dimension_diameter                      primary_diagnosis  \
# 0                        Not Reported  Invasive carcinoma of no special type
# 1                        Not Reported                           Not Reported
# 2                        Not Reported                           Not Reported
# 3                        Not Reported                           Not Reported
# 4                        Not Reported  Invasive carcinoma of no special type
# ...                               ...                                    ...
# 1063                                1                 Endometrioid carcinoma
# 1064                              4.2                 Endometrioid carcinoma
# 1065                              1.5              Serous cystadenocarcinoma
# 1066                              3.8              Serous cystadenocarcinoma
# 1067                                5              Serous cystadenocarcinoma
#
#         morphology tissue_or_organ_of_origin tumor_code study
# 0           8500/3               Breast, NOS       BRCA  Krug
# 1     Not Reported               Breast, NOS       BRCA  Krug
# 2     Not Reported               Breast, NOS       BRCA  Krug
# 3     Not Reported               Breast, NOS       BRCA  Krug
# 4           8500/3               Breast, NOS       BRCA  Krug
# ...            ...                       ...        ...   ...
# 1063        8380/3               Endometrium       UCEC   Dou
# 1064        8380/3               Endometrium       UCEC   Dou
# 1065        8441/3               Endometrium       UCEC   Dou
# 1066        8441/3               Endometrium       UCEC   Dou
# 1067        8441/3               Endometrium       UCEC   Dou
#
# [1068 rows x 17 columns]

# %%
fdf = df_target[df_target['study'] == 'Krug']
fdf
# Out:
#     case_submitter_id  age_at_diagnosis                       race  \
# 0             01BR001           20089.0  black or african american
# 1             01BR008           17532.0  black or african american
# 2             01BR009           23376.0  black or african american
# 3             01BR010           23741.0  black or african american
# 4             01BR015           12784.0                      white
# ..                ...               ...                        ...
# 115           21BR001           31412.0                      white
# 116           21BR002           31412.0                      white
# 117           21BR010           25933.0                      white
# 118           22BR005           16802.0                      white
# 119           22BR006           20089.0  black or african american
#
#                   ethnicity  gender  vital_status ajcc_pathologic_t  \
# 0    not hispanic or latino  female         Alive                T2
# 1    not hispanic or latino  female  Not Reported      Not Reported
# 2    not hispanic or latino  female  Not Reported      Not Reported
# 3    not hispanic or latino  female  Not Reported      Not Reported
# 4    not hispanic or latino  female         Alive                T2
# ..                      ...     ...           ...               ...
# 115      hispanic or latino  female  Not Reported      Not Reported
# 116      hispanic or latino  female  Not Reported      Not Reported
# 117      hispanic or latino  female         Alive                T2
# 118  not hispanic or latino  female         Alive                T2
# 119  not hispanic or latino  female          Dead                T3
#
#     ajcc_pathologic_n ajcc_pathologic_stage tumor_grade tumor_focality  \
# 0                 N1c              Stage II          GX   Not Reported
# 1        Not Reported          Not Reported          GX   Not Reported
# 2        Not Reported          Not Reported          GX   Not Reported
# 3        Not Reported          Not Reported          GX   Not Reported
# 4                  N1              Stage II          GX   Not Reported
# ..                ...                   ...         ...            ...
# 115      Not Reported          Not Reported          GX   Not Reported
# 116      Not Reported          Not Reported          GX   Not Reported
# 117               N1a              Stage II          GX   Not Reported
# 118               N1a              Stage II          GX   Not Reported
# 119                N1             Stage III          GX   Not Reported
#
#     tumor_largest_dimension_diameter                        primary_diagnosis  \
# 0                       Not Reported    Invasive carcinoma of no special type
# 1                       Not Reported                             Not Reported
# 2                       Not Reported                             Not Reported
# 3                       Not Reported                             Not Reported
# 4                       Not Reported    Invasive carcinoma of no special type
# ..                               ...                                      ...
# 115                     Not Reported                             Not Reported
# 116                     Not Reported                             Not Reported
# 117                     Not Reported    Invasive carcinoma of no special type
# 118                     Not Reported  Infiltrating duct and lobular carcinoma
# 119                     Not Reported    Invasive carcinoma of no special type
#
#        morphology tissue_or_organ_of_origin tumor_code study
# 0          8500/3               Breast, NOS       BRCA  Krug
# 1    Not Reported               Breast, NOS       BRCA  Krug
# 2    Not Reported               Breast, NOS       BRCA  Krug
# 3    Not Reported               Breast, NOS       BRCA  Krug
# 4          8500/3               Breast, NOS       BRCA  Krug
# ..            ...                       ...        ...   ...
# 115  Not Reported               Breast, NOS       BRCA  Krug
# 116  Not Reported               Breast, NOS       BRCA  Krug
# 117        8500/3               Breast, NOS       BRCA  Krug
# 118        8522/3               Breast, NOS       BRCA  Krug
# 119        8500/3               Breast, NOS       BRCA  Krug
#
# [120 rows x 17 columns]

# %%
unique_values = df_target['study'].unique()
unique_values
# Out:
# array(['Krug', 'Clark', 'Vasaikar', 'Wang', 'McDermott', 'Huang',
#        'Satpathy', 'Gilette', 'Cao', 'Dou'], dtype=object)

# %%
# for column in df_target.columns:
#     print(f"Column: {column}")
#     print(f"Distinct Values: {df_target[column].nunique()}")
#     if df_target[column].nunique() < 20:
#         print(f"Distribution for {df_target[column].value_counts()}:\n")

# %%
folder_path = 'table-matching-ground-truth/ground-truth/' 
gdc_format_variable_names = set()
for file_name in os.listdir(folder_path):
    file_path = os.path.join(folder_path, file_name)
    if os.path.isfile(file_path) and file_name.endswith('.csv'):
        df = pd.read_csv(file_path)  
        gdc_format_variable_names.update(set(df['GDC_format_variable_names'].unique()))

len(gdc_format_variable_names)

target_cols = set(df_target.columns)

intersection = gdc_format_variable_names.intersection(target_cols)
difference = target_cols.difference(gdc_format_variable_names)



intersection.remove('case_submitter_id')

print(intersection)
print(difference)
# Out:
# {'tissue_or_organ_of_origin', 'ethnicity', 'ajcc_pathologic_n', 'primary_diagnosis', 'tumor_focality', 'gender', 'ajcc_pathologic_t', 'race', 'age_at_diagnosis', 'vital_status', 'ajcc_pathologic_stage', 'tumor_largest_dimension_diameter', 'tumor_grade'}
# {'study', 'morphology', 'tumor_code'}

# %%
gt_path = 'table-matching-ground-truth/ground-truth_revised/'
data_path = 'extracted-tables-revised/'
gdc_format_variable_names = set()

id_names = ['Case_ID', 'idx', 'Sample.ID',
            'case_id', 'SampleID', 'Participant']

possible_nulls = ['Not Reported',  'unknown', 'NaN', pd.NA, np.nan] 

for gt_file_name in os.listdir(gt_path):
    gt_file_path = os.path.join(gt_path, gt_file_name)
    if os.path.isfile(gt_file_path) and gt_file_name.endswith('.csv'):

        study = gt_file_name.replace('.csv', '')
        print(f"Study: {study}")

        dfs = []
        for data_file_name in os.listdir(data_path):
            # print(data_file_name)
            data_file_path = os.path.join(data_path, data_file_name)

            if os.path.isfile(data_file_path) and data_file_name.startswith(study) and data_file_name.endswith('.csv'):
                df = pd.read_csv(data_file_path)
                dfs.append(df)
        # print(f"Ground Truth File: {gt_file_name} with {len(dfs)} data files")

        df_ground = pd.read_csv(gt_file_path)

        study_key = df_ground[df_ground['GDC_format_variable_names'] ==
                              'case_submitter_id']['original_paper_variable_names'].values[0]

        for target_col in df_ground['GDC_format_variable_names'].unique():

            if target_col not in intersection:
                continue

            study_col = df_ground[df_ground['GDC_format_variable_names']
                                  == target_col]['original_paper_variable_names'].values[0]
            # print(f"Study: {study_col}")

            dfs = [df for df in dfs if study_col in df.columns]

            if len(dfs) == 0:
                print(f"Target: {target_col} not found in any data files")
                continue
            if len(dfs) > 1:
                print(f"Target: {target_col} found in multiple data files")
                continue

            study_df = dfs[0]

            if study_key not in study_df.columns:
                continue

            # print(study_key)

            if study == 'Krug':
                # print(study_key)
                # print(study_df.head())
                if study_key in study_df.columns:
                    study_df['Sample.ID'] = study_df['Sample.ID'].str.replace(
                        '^X', '', regex=True)
                    


            partial_df_target = df_target[df_target["study"] == study]
            partial_df_target = partial_df_target[[
                'case_submitter_id', target_col]]

            partial_df_study = study_df[[study_key, study_col]]

            join_df = pd.merge(partial_df_study, partial_df_target,
                               left_on=study_key, right_on='case_submitter_id', how='inner')

            if join_df.shape[0] == 0:
                print(f"Joining {study} failed for column {target_col}")
                print(join_df.head())
                print('\n')


                # print(join_df.head())
                # print('\n')


            # print(join_df.head(5))
            # print('\n')
            file_name = f"{study}_{target_col}.csv"

            value_gt_path = 'value-matching-ground-truth/extracted/'
            join_df.to_csv(os.path.join(value_gt_path, file_name), index=False)

            value_gt_path = 'value-matching-ground-truth/deduplicated/'
            deuduplicaded_df = join_df.drop_duplicates()
            deuduplicaded_df.to_csv(os.path.join(value_gt_path, file_name), index=False)

            value_gt_path = 'value-matching-ground-truth/deduplicated_nonull/'    
            nonnull = join_df[~join_df.isin(possible_nulls).any(axis=1)]
            nonnull = nonnull.drop_duplicates()
            nonnull.to_csv(os.path.join(value_gt_path, file_name), index=False)


            # print(join_df.head(5))
            # print('\n')
# Out:
# Study: Krug
#   Sample.ID Tumor.Stage case_submitter_id ajcc_pathologic_stage
# 0   01BR001   Stage IIB           01BR001              Stage II
# 4   01BR015   Stage IIB           01BR015              Stage II
# 5   01BR017   Stage III           01BR017             Stage III
# 6   01BR018  Stage IIIA           01BR018             Stage III
# 9   01BR025  Stage IIIA           01BR025             Stage III
#
#
#   Sample.ID Age.in.Month case_submitter_id  age_at_diagnosis
# 0   01BR001          660           01BR001           20089.0
# 4   01BR015          420           01BR015           12784.0
# 5   01BR017          540           01BR017           16436.0
# 6   01BR018          792           01BR018           24106.0
# 9   01BR025          744           01BR025           22646.0
#
#
#   Sample.ID  Gender case_submitter_id  gender
# 0   01BR001  female           01BR001  female
# 4   01BR015  female           01BR015  female
# 5   01BR017  female           01BR017  female
# 6   01BR018  female           01BR018  female
# 9   01BR025  female           01BR025  female
#
#
#   Sample.ID                  Ethnicity case_submitter_id  \
# 0   01BR001  black.or.african.american           01BR001
# 4   01BR015                      white           01BR015
# 5   01BR017                      white           01BR017
# 6   01BR018                      white           01BR018
# 9   01BR025  black.or.african.american           01BR025
#
#                 ethnicity
# 0  not hispanic or latino
# 4  not hispanic or latino
# 5  not hispanic or latino
# 6  not hispanic or latino
# 9  not hispanic or latino
#
#
# Study: Clark
#      Case_ID  Gender case_submitter_id  gender
# 0  C3L-00004    Male         C3L-00004    male
# 1  C3L-00010    Male         C3L-00010    male
# 2  C3L-00011  Female         C3L-00011  female
# 3  C3L-00026  Female         C3L-00026  female
# 4  C3L-00079    Male         C3L-00079    male
#
#
#      Case_ID Age case_submitter_id  age_at_diagnosis
# 0  C3L-00004  72         C3L-00004           26298.0
# 1  C3L-00010  30         C3L-00010           10958.0
# 2  C3L-00011  63         C3L-00011           23011.0
# 3  C3L-00026  65         C3L-00026           23741.0
# 4  C3L-00079  49         C3L-00079           17897.0
#
#
#      Case_ID   Race case_submitter_id   race
# 0  C3L-00004  White         C3L-00004  white
# 1  C3L-00010  White         C3L-00010  white
# 2  C3L-00011  White         C3L-00011  white
# 3  C3L-00026  White         C3L-00026  white
# 4  C3L-00079  White         C3L-00079  white
#
#
#      Case_ID Ethnicity_Self_Identify case_submitter_id               ethnicity
# 0  C3L-00004                   White         C3L-00004  not hispanic or latino
# 1  C3L-00010                   White         C3L-00010  not hispanic or latino
# 2  C3L-00011                   White         C3L-00011  not hispanic or latino
# 3  C3L-00026                   White         C3L-00026  not hispanic or latino
# 4  C3L-00079                   white         C3L-00079  not hispanic or latino
#
#
#      Case_ID  Tumor_Size_cm case_submitter_id tumor_largest_dimension_diameter
# 0  C3L-00004           12.0         C3L-00004                               12
# 1  C3L-00010            6.5         C3L-00010                              6.5
# 2  C3L-00011           12.0         C3L-00011                               12
# 3  C3L-00026            2.0         C3L-00026                                2
# 4  C3L-00079           14.0         C3L-00079                               14
#
#
#      Case_ID Tumor_Focality case_submitter_id tumor_focality
# 0  C3L-00004       Unifocal         C3L-00004       Unifocal
# 1  C3L-00010       Unifocal         C3L-00010       Unifocal
# 2  C3L-00011       Unifocal         C3L-00011       Unifocal
# 3  C3L-00026       Unifocal         C3L-00026       Unifocal
# 4  C3L-00079       Unifocal         C3L-00079       Unifocal
#
#
#      Case_ID                  Histologic_Type case_submitter_id  \
# 0  C3L-00004  Clear cell renal cell carcinoma         C3L-00004
# 1  C3L-00010  Clear cell renal cell carcinoma         C3L-00010
# 2  C3L-00011  Clear cell renal cell carcinoma         C3L-00011
# 3  C3L-00026  Clear cell renal cell carcinoma         C3L-00026
# 4  C3L-00079  Clear cell renal cell carcinoma         C3L-00079
#
#       primary_diagnosis
# 0  Renal cell carcinoma
# 1  Renal cell carcinoma
# 2  Renal cell carcinoma
# 3  Renal cell carcinoma
# 4  Renal cell carcinoma
#
#
#      Case_ID Grade case_submitter_id tumor_grade
# 0  C3L-00004    G3         C3L-00004          G3
# 1  C3L-00010    G3         C3L-00010          G3
# 2  C3L-00011    G4         C3L-00011          G4
# 3  C3L-00026    G3         C3L-00026          G3
# 4  C3L-00079    G3         C3L-00079          G3
#
#
#      Case_ID Tumor_Stage_Pathological case_submitter_id ajcc_pathologic_stage
# 0  C3L-00004                Stage III         C3L-00004             Stage III
# 1  C3L-00010                  Stage I         C3L-00010               Stage I
# 2  C3L-00011                 Stage IV         C3L-00011              Stage IV
# 3  C3L-00026                  Stage I         C3L-00026               Stage I
# 4  C3L-00079                Stage III         C3L-00079             Stage III
#
#
#      Case_ID Path_Stage_Primary_Tumor_pT case_submitter_id ajcc_pathologic_t
# 0  C3L-00004                         pT3         C3L-00004                T3
# 1  C3L-00010                        pT1b         C3L-00010               T1b
# 2  C3L-00011                        pT3a         C3L-00011               T3a
# 3  C3L-00026                        pT1a         C3L-00026               T1a
# 4  C3L-00079                        pT3a         C3L-00079               T3a
#
#
#      Case_ID Path_Stage_Reg_Lymph_Nodes_pN case_submitter_id ajcc_pathologic_n
# 0  C3L-00004                           pNX         C3L-00004                NX
# 1  C3L-00010                           pN0         C3L-00010                N0
# 2  C3L-00011                           pNX         C3L-00011                NX
# 3  C3L-00026                           pNX         C3L-00026                NX
# 4  C3L-00079                           pN1         C3L-00079                N1
#
#
# Study: Vasaikar
#   SampleID  Age case_submitter_id  age_at_diagnosis
# 0  01CO005  838           01CO005           25202.0
# 1  01CO006  904           01CO006           27394.0
# 2  01CO008  652           01CO008           19724.0
# 3  01CO013  695           01CO013           20819.0
# 4  01CO014  930           01CO014           28124.0
#
#
#   SampleID  Gender case_submitter_id  gender
# 0  01CO005  Female           01CO005  female
# 1  01CO006  Female           01CO006  female
# 2  01CO008  Female           01CO008  female
# 3  01CO013    Male           01CO013    male
# 4  01CO014  Female           01CO014  female
#
#
#   SampleID   PT case_submitter_id ajcc_pathologic_t
# 0  01CO005   T3           01CO005                T3
# 1  01CO006  T4a           01CO006               T4a
# 2  01CO008   T3           01CO008                T3
# 3  01CO013   T2           01CO013                T2
# 4  01CO014   T3           01CO014                T3
#
#
#   SampleID   PN case_submitter_id ajcc_pathologic_n
# 0  01CO005   N0           01CO005                N0
# 1  01CO006  N2b           01CO006               N2b
# 2  01CO008   N0           01CO008                N0
# 3  01CO013   N0           01CO013                N0
# 4  01CO014  N2a           01CO014               N2a
#
#
#   SampleID      Stage case_submitter_id ajcc_pathologic_stage
# 0  01CO005   Stage II           01CO005              Stage II
# 1  01CO006  Stage III           01CO006             Stage III
# 2  01CO008   Stage II           01CO008              Stage II
# 3  01CO013    Stage I           01CO013               Stage I
# 4  01CO014  Stage III           01CO014             Stage III
#
#
#   SampleID Vital.Status case_submitter_id vital_status
# 0  01CO005     Deceased           01CO005         Dead
# 1  01CO006       Living           01CO006        Alive
# 2  01CO008       Living           01CO008        Alive
# 3  01CO013       Living           01CO013        Alive
# 4  01CO014       Living           01CO014        Alive
#
#
# Study: Wang
#      case_id  age case_submitter_id  age_at_diagnosis
# 0  C3L-00104   58         C3L-00104           21184.0
# 1  C3L-00365   59         C3L-00365           21550.0
# 2  C3L-00674   45         C3L-00674           16436.0
# 3  C3L-00677   69         C3L-00677           25202.0
# 4  C3L-01040   77         C3L-01040           28124.0
#
#
#      case_id gender_x case_submitter_id gender_y
# 0  C3L-00104     Male         C3L-00104     male
# 1  C3L-00365   Female         C3L-00365   female
# 2  C3L-00674     Male         C3L-00674     male
# 3  C3L-00677   Female         C3L-00677   female
# 4  C3L-01040     Male         C3L-01040     male
#
#
#       case_id race_x case_submitter_id race_y
# 0   C3L-00104  White         C3L-00104  white
# 1   C3L-00365  White         C3L-00365  white
# 2   C3L-00674  White         C3L-00674  white
# 3   C3L-00677  White         C3L-00677  white
# 18  C3L-01327  White         C3L-01327  white
#
#
#       case_id             ethnicity_x case_submitter_id  \
# 0   C3L-00104  Not-Hispanic or Latino         C3L-00104
# 1   C3L-00365  Not-Hispanic or Latino         C3L-00365
# 2   C3L-00674  Not-Hispanic or Latino         C3L-00674
# 3   C3L-00677  Not-Hispanic or Latino         C3L-00677
# 18  C3L-01327  Not-Hispanic or Latino         C3L-01327
#
#                ethnicity_y
# 0   not hispanic or latino
# 1   not hispanic or latino
# 2   not hispanic or latino
# 3   not hispanic or latino
# 18  not hispanic or latino
#
#
#      case_id vital_status_x case_submitter_id vital_status_y
# 0  C3L-00104       Deceased         C3L-00104           Dead
# 1  C3L-00365       Deceased         C3L-00365           Dead
# 2  C3L-00674       Deceased         C3L-00674           Dead
# 3  C3L-00677       Deceased         C3L-00677           Dead
# 4  C3L-01040         Living         C3L-01040          Alive
#
#
# Study: Satpathy
#   Participant Stage case_submitter_id ajcc_pathologic_stage
# 1   C3L-00081   IIA         C3L-00081              Stage II
# 3   C3L-00415   IIA         C3L-00415              Stage II
# 5   C3L-00445   IIA         C3L-00445              Stage II
# 7   C3L-00568    IB         C3L-00568               Stage I
# 9   C3L-00603    IA         C3L-00603               Stage I
#
#
#   Participant  Age case_submitter_id  age_at_diagnosis
# 0   C3L-00081   61         C3L-00081           22280.0
# 1   C3L-00081   61         C3L-00081           22280.0
# 2   C3L-00415   64         C3L-00415           23376.0
# 3   C3L-00415   64         C3L-00415           23376.0
# 4   C3L-00445   74         C3L-00445           27028.0
#
#
#   Participant  Gender case_submitter_id  gender
# 0   C3L-00081  female         C3L-00081  female
# 1   C3L-00081  female         C3L-00081  female
# 2   C3L-00415  female         C3L-00415  female
# 3   C3L-00415  female         C3L-00415  female
# 4   C3L-00445    male         C3L-00445    male
#
#
#   Participant  Ethnicity case_submitter_id               ethnicity
# 0   C3L-00081  caucasian         C3L-00081  not hispanic or latino
# 1   C3L-00081  caucasian         C3L-00081  not hispanic or latino
# 2   C3L-00415  caucasian         C3L-00415  not hispanic or latino
# 3   C3L-00415  caucasian         C3L-00415  not hispanic or latino
# 6   C3L-00568  caucasian         C3L-00568      hispanic or latino
#
#
# Study: Cao
#      case_id  age case_submitter_id  age_at_diagnosis
# 0  C3L-00102   42         C3L-00102           15340.0
# 1  C3L-00189   68         C3L-00189           24837.0
# 2  C3L-00277   69         C3L-00277           25202.0
# 3  C3L-00401   62         C3L-00401           22646.0
# 4  C3L-00640   59         C3L-00640           21550.0
#
#
#      case_id     sex case_submitter_id  gender
# 0  C3L-00102    Male         C3L-00102    male
# 1  C3L-00189  Female         C3L-00189  female
# 2  C3L-00277    Male         C3L-00277    male
# 3  C3L-00401  Female         C3L-00401  female
# 4  C3L-00640  Female         C3L-00640  female
#
#
#      case_id race_x case_submitter_id race_y
# 0  C3L-00102  White         C3L-00102  white
# 2  C3L-00277  White         C3L-00277  white
# 4  C3L-00640  White         C3L-00640  white
# 5  C3L-00819  White         C3L-00819  white
# 6  C3L-00881  White         C3L-00881  white
#
#
#      case_id tumor_focality_x case_submitter_id tumor_focality_y
# 0  C3L-00102         Unifocal         C3L-00102         Unifocal
# 1  C3L-00189         Unifocal         C3L-00189         Unifocal
# 2  C3L-00277         Unifocal         C3L-00277         Unifocal
# 3  C3L-00401         Unifocal         C3L-00401         Unifocal
# 4  C3L-00640         Unifocal         C3L-00640         Unifocal
#
#
#      case_id  tumor_size_cm case_submitter_id tumor_largest_dimension_diameter
# 0  C3L-00102            3.0         C3L-00102                                3
# 1  C3L-00189            2.7         C3L-00189                              2.7
# 2  C3L-00277            5.0         C3L-00277                                5
# 3  C3L-00401            2.8         C3L-00401                              2.8
# 4  C3L-00640            4.5         C3L-00640                              4.5
#
#
#      case_id pathologic_staging_regional_lymph_nodes_pn case_submitter_id  \
# 0  C3L-00102                                        pN2         C3L-00102
# 1  C3L-00189                                        pN1         C3L-00189
# 2  C3L-00277                                        pN1         C3L-00277
# 3  C3L-00401                                        pN1         C3L-00401
# 4  C3L-00640                                        pN1         C3L-00640
#
#   ajcc_pathologic_n
# 0                N1
# 1                N1
# 2                N1
# 3                N1
# 4                N1
#
#
#      case_id pathologic_staging_primary_tumor_pt case_submitter_id  \
# 0  C3L-00102                                 pT2         C3L-00102
# 1  C3L-00189                                 pT2         C3L-00189
# 2  C3L-00277                                 pT3         C3L-00277
# 3  C3L-00401                                 pT2         C3L-00401
# 4  C3L-00640                                 pT3         C3L-00640
#
#   ajcc_pathologic_t
# 0                T3
# 1                T3
# 2                T3
# 3                T3
# 4                T3
#
#
#      case_id tumor_stage_pathological case_submitter_id ajcc_pathologic_stage
# 0  C3L-00102                Stage III         C3L-00102              Stage II
# 1  C3L-00189                Stage IIB         C3L-00189              Stage II
# 2  C3L-00277                Stage IIB         C3L-00277              Stage II
# 3  C3L-00401                Stage IIB         C3L-00401              Stage II
# 4  C3L-00640                Stage IIB         C3L-00640              Stage II
#
#
#      case_id vital_status_x case_submitter_id vital_status_y
# 0  C3L-00102       Deceased         C3L-00102           Dead
# 1  C3L-00189       Deceased         C3L-00189           Dead
# 2  C3L-00277       Deceased         C3L-00277           Dead
# 3  C3L-00401         Living         C3L-00401           Dead
# 4  C3L-00640         Living         C3L-00640          Alive
#
#
# Study: Huang
#      case_id  age case_submitter_id  age_at_diagnosis
# 0  C3L-00977   56         C3L-00977           20454.0
# 1  C3L-00987   61         C3L-00987           22280.0
# 2  C3L-00994   50         C3L-00994           18262.0
# 3  C3L-00995   56         C3L-00995           20454.0
# 4  C3L-00997   47         C3L-00997           17167.0
#
#
#      case_id gender_x case_submitter_id gender_y
# 0  C3L-00977     Male         C3L-00977     male
# 1  C3L-00987     Male         C3L-00987     male
# 2  C3L-00994     Male         C3L-00994     male
# 3  C3L-00995     Male         C3L-00995     male
# 4  C3L-00997     Male         C3L-00997     male
#
#
#      case_id tumor_focality_x case_submitter_id tumor_focality_y
# 0  C3L-00977         Unifocal         C3L-00977         Unifocal
# 1  C3L-00987         Unifocal         C3L-00987         Unifocal
# 2  C3L-00994         Unifocal         C3L-00994         Unifocal
# 3  C3L-00995         Unifocal         C3L-00995         Unifocal
# 4  C3L-00997         Unifocal         C3L-00997         Unifocal
#
#
#      case_id  tumor_size_cm case_submitter_id tumor_largest_dimension_diameter
# 0  C3L-00977            1.2         C3L-00977                              1.2
# 1  C3L-00987            4.0         C3L-00987                                4
# 2  C3L-00994            3.0         C3L-00994                                3
# 3  C3L-00995            4.0         C3L-00995                                4
# 4  C3L-00997            4.0         C3L-00997                                4
#
#
#      case_id                        histologic_type case_submitter_id  \
# 0  C3L-00977  Squamous cell carcinoma, conventional         C3L-00977
# 1  C3L-00987  Squamous cell carcinoma, conventional         C3L-00987
# 2  C3L-00994  Squamous cell carcinoma, conventional         C3L-00994
# 3  C3L-00995  Squamous cell carcinoma, conventional         C3L-00995
# 4  C3L-00997  Squamous cell carcinoma, conventional         C3L-00997
#
#               primary_diagnosis
# 0  Squamous cell carcinoma, NOS
# 1  Squamous cell carcinoma, NOS
# 2  Squamous cell carcinoma, NOS
# 3  Squamous cell carcinoma, NOS
# 4  Squamous cell carcinoma, NOS
#
#
#      case_id              histologic_grade case_submitter_id tumor_grade
# 0  C3L-00977        G1 Well differentiated         C3L-00977          G1
# 1  C3L-00987  G2 Moderately differentiated         C3L-00987          G2
# 2  C3L-00994  G2 Moderately differentiated         C3L-00994          G2
# 3  C3L-00995        G1 Well differentiated         C3L-00995          G1
# 4  C3L-00997  G2 Moderately differentiated         C3L-00997          G2
#
#
#      case_id patho_staging_pt case_submitter_id ajcc_pathologic_t
# 0  C3L-00977              pT1         C3L-00977                T1
# 1  C3L-00987              pT2         C3L-00987                T2
# 2  C3L-00994              pT2         C3L-00994                T2
# 3  C3L-00995              pT2         C3L-00995                T2
# 4  C3L-00997              pT2         C3L-00997                T2
#
#
#      case_id patho_staging_pn case_submitter_id ajcc_pathologic_n
# 0  C3L-00977              pN1         C3L-00977                N1
# 1  C3L-00987              pN1         C3L-00987                N1
# 2  C3L-00994              pN0         C3L-00994                N0
# 3  C3L-00995              pN1         C3L-00995                N1
# 4  C3L-00997              pN1         C3L-00997                N1
#
#
#      case_id tumor_stage case_submitter_id ajcc_pathologic_stage
# 0  C3L-00977   Stage III         C3L-00977             Stage III
# 1  C3L-00987   Stage III         C3L-00987             Stage III
# 2  C3L-00994    Stage II         C3L-00994              Stage II
# 3  C3L-00995   Stage III         C3L-00995             Stage III
# 4  C3L-00997    Stage II         C3L-00997              Stage II
#
#
# Study: Dou
#   Proteomics_Participant_ID Histologic_Grade_FIGO case_submitter_id  \
# 0                 C3L-00006          FIGO grade 1         C3L-00006
# 2                 C3L-00008          FIGO grade 1         C3L-00008
# 3                 C3L-00032          FIGO grade 2         C3L-00032
# 4                 C3L-00090          FIGO grade 2         C3L-00090
# 6                 C3L-00136          FIGO grade 1         C3L-00136
#
#   tumor_grade
# 0          G1
# 2          G1
# 3          G2
# 4          G2
# 6          G1
#
#
#   Proteomics_Participant_ID Histologic_type case_submitter_id  \
# 0                 C3L-00006    Endometrioid         C3L-00006
# 2                 C3L-00008    Endometrioid         C3L-00008
# 3                 C3L-00032    Endometrioid         C3L-00032
# 4                 C3L-00090    Endometrioid         C3L-00090
# 5                 C3L-00098          Serous         C3L-00098
#
#         primary_diagnosis
# 0  Endometrioid carcinoma
# 2  Endometrioid carcinoma
# 3  Endometrioid carcinoma
# 4  Endometrioid carcinoma
# 5  Endometrioid carcinoma
#
#
#   Proteomics_Participant_ID Path_Stage_Primary_Tumor-pT case_submitter_id  \
# 0                 C3L-00006              pT1a (FIGO IA)         C3L-00006
# 2                 C3L-00008              pT1a (FIGO IA)         C3L-00008
# 3                 C3L-00032              pT1a (FIGO IA)         C3L-00032
# 4                 C3L-00090              pT1a (FIGO IA)         C3L-00090
# 5                 C3L-00098              pT1a (FIGO IA)         C3L-00098
#
#   ajcc_pathologic_t
# 0               T1a
# 2               T1a
# 3               T1a
# 4               T1a
# 5               T1a
#
#
#   Proteomics_Participant_ID Path_Stage_Reg_Lymph_Nodes-pN case_submitter_id  \
# 0                 C3L-00006                           pN0         C3L-00006
# 2                 C3L-00008                           pNX         C3L-00008
# 3                 C3L-00032                           pN0         C3L-00032
# 4                 C3L-00090                           pNX         C3L-00090
# 5                 C3L-00098                           pNX         C3L-00098
#
#   ajcc_pathologic_n
# 0                N0
# 2                NX
# 3                N0
# 4                NX
# 5                NX
#
#
#   Proteomics_Participant_ID tumor_Stage-Pathological case_submitter_id  \
# 0                 C3L-00006                  Stage I         C3L-00006
# 2                 C3L-00008                 Stage IV         C3L-00008
# 3                 C3L-00032                  Stage I         C3L-00032
# 4                 C3L-00090                  Stage I         C3L-00090
# 5                 C3L-00098                  Stage I         C3L-00098
#
#   ajcc_pathologic_stage
# 0               Stage I
# 2               Stage I
# 3               Stage I
# 4               Stage I
# 5               Stage I
#
#
#   Proteomics_Participant_ID   Age case_submitter_id  age_at_diagnosis
# 0                 C3L-00006  64.0         C3L-00006           23376.0
# 2                 C3L-00008  58.0         C3L-00008           21184.0
# 3                 C3L-00032  50.0         C3L-00032           18262.0
# 4                 C3L-00090  75.0         C3L-00090           27394.0
# 5                 C3L-00098  63.0         C3L-00098           23011.0
#
#
#   Proteomics_Participant_ID   Race case_submitter_id   race
# 0                 C3L-00006  White         C3L-00006  white
# 2                 C3L-00008  White         C3L-00008  white
# 3                 C3L-00032  White         C3L-00032  white
# 4                 C3L-00090  White         C3L-00090  white
# 5                 C3L-00098  White         C3L-00098  white
#
#
#   Proteomics_Participant_ID               Ethnicity case_submitter_id  \
# 0                 C3L-00006  Not-Hispanic or Latino         C3L-00006
# 2                 C3L-00008  Not-Hispanic or Latino         C3L-00008
# 3                 C3L-00032  Not-Hispanic or Latino         C3L-00032
# 4                 C3L-00090  Not-Hispanic or Latino         C3L-00090
# 5                 C3L-00098  Not-Hispanic or Latino         C3L-00098
#
#                 ethnicity
# 0  not hispanic or latino
# 2  not hispanic or latino
# 3  not hispanic or latino
# 4  not hispanic or latino
# 5  not hispanic or latino
#
#
#   Proteomics_Participant_ID  Gender case_submitter_id  gender
# 0                 C3L-00006  Female         C3L-00006  female
# 2                 C3L-00008  Female         C3L-00008  female
# 3                 C3L-00032  Female         C3L-00032  female
# 4                 C3L-00090  Female         C3L-00090  female
# 5                 C3L-00098  Female         C3L-00098  female
#
#
#   Proteomics_Participant_ID             Tumor_Site case_submitter_id  \
# 0                 C3L-00006   Anterior endometrium         C3L-00006
# 2                 C3L-00008  Posterior endometrium         C3L-00008
# 3                 C3L-00032         Other, specify         C3L-00032
# 4                 C3L-00090         Other, specify         C3L-00090
# 5                 C3L-00098         Other, specify         C3L-00098
#
#   tissue_or_organ_of_origin
# 0               Endometrium
# 2               Endometrium
# 3               Endometrium
# 4               Endometrium
# 5               Endometrium
#
#
#   Proteomics_Participant_ID Tumor_Focality case_submitter_id tumor_focality
# 0                 C3L-00006       Unifocal         C3L-00006       Unifocal
# 2                 C3L-00008       Unifocal         C3L-00008       Unifocal
# 3                 C3L-00032       Unifocal         C3L-00032       Unifocal
# 4                 C3L-00090       Unifocal         C3L-00090       Unifocal
# 5                 C3L-00098       Unifocal         C3L-00098       Unifocal
#
#
#   Proteomics_Participant_ID  Tumor_Size_cm case_submitter_id  \
# 0                 C3L-00006            2.9         C3L-00006
# 2                 C3L-00008            3.5         C3L-00008
# 3                 C3L-00032            4.5         C3L-00032
# 4                 C3L-00090            3.5         C3L-00090
# 5                 C3L-00098            6.0         C3L-00098
#
#   tumor_largest_dimension_diameter
# 0                              2.9
# 2                              3.5
# 3                              4.5
# 4                              3.5
# 5                                6
#
#
# Study: Gilette
#   Participant   Age case_submitter_id  age_at_diagnosis
# 0   C3N-01799  81.0         C3N-01799           29585.0
# 1   C3N-01799  81.0         C3N-01799           29585.0
# 2   C3L-01890  58.0         C3L-01890           21184.0
# 3   C3L-01890  58.0         C3L-01890           21184.0
# 4   C3N-00572  48.0         C3N-00572           17532.0
#
#
#   Participant  Gender case_submitter_id  gender
# 0   C3N-01799    male         C3N-01799    male
# 1   C3N-01799    male         C3N-01799    male
# 2   C3L-01890  female         C3L-01890  female
# 3   C3L-01890  female         C3L-01890  female
# 4   C3N-00572  female         C3N-00572  female
#
#
#    Participant  Ethnicity case_submitter_id               ethnicity
# 0    C3N-01799  caucasian         C3N-01799  not hispanic or latino
# 1    C3N-01799  caucasian         C3N-01799  not hispanic or latino
# 2    C3L-01890  caucasian         C3L-01890  not hispanic or latino
# 3    C3L-01890  caucasian         C3L-01890  not hispanic or latino
# 10   C3L-00263  caucasian         C3L-00263  not hispanic or latino
#
#
#   Participant Dominant.Histological.Subtype case_submitter_id  \
# 0   C3N-01799                        acinar         C3N-01799
# 2   C3L-01890                        acinar         C3L-01890
# 4   C3N-00572                micropapillary         C3N-00572
# 6   C3N-02423                        acinar         C3N-02423
# 8   C3N-02729                        acinar         C3N-02729
#
#         primary_diagnosis
# 0     Adenocarcinoma, NOS
# 2  Lepidic adenocarcinoma
# 4     Adenocarcinoma, NOS
# 6     Adenocarcinoma, NOS
# 8     Adenocarcinoma, NOS
