# %%
import pandas as pd

df = pd.read_csv('target.csv')
df
# Out:
#      case_submitter_id  age_at_diagnosis                       race  \
# 0              01BR001           20089.0  black or african american
# 1              01BR008           17532.0  black or african american
# 2              01BR009           23376.0  black or african american
# 3              01BR010           23741.0  black or african american
# 4              01BR015           12784.0                      white
# ...                ...               ...                        ...
# 1063         C3N-01520           25202.0               Not Reported
# 1064         C3N-01521           27394.0               Not Reported
# 1065         C3N-01537           27028.0               Not Reported
# 1066         C3N-01802           31046.0  black or african american
# 1067         C3N-01825           25568.0               Not Reported
#
#                    ethnicity  gender  vital_status ajcc_pathologic_t  \
# 0     not hispanic or latino  female         Alive                T2
# ...

# %%
unique_values = df['study'].unique()
unique_values
# Out:
# array(['Krug', 'Clark', 'Vasaikar', 'Wang', 'McDermott', 'Huang',
#        'Satpathy', 'Gilette', 'Cao', 'Dou'], dtype=object)

# %%
for column in df.columns:
    print(f"Column: {column}")
    print(f"Distinct Values: {df[column].nunique()}")
    if df[column].nunique() < 20:
        print(f"Distribution for {df[column].value_counts()}:\n")
# Out:
# Column: case_submitter_id
# Distinct Values: 1068
# Column: age_at_diagnosis
# Distinct Values: 62
# Column: race
# Distinct Values: 5
# Distribution for race
# Not Reported                        528
# white                               456
# asian                                46
# black or african american            35
# american indian or alaska native      3
# Name: count, dtype: int64:
#
# Column: ethnicity
# Distinct Values: 3
# Distribution for ethnicity
# Not Reported              550
# not hispanic or latino    484
# hispanic or latino         34
# Name: count, dtype: int64:
#
# Column: gender
# Distinct Values: 2
# Distribution for gender
# female    565
# male      503
# Name: count, dtype: int64:
#
# Column: vital_status
# Distinct Values: 3
# Distribution for vital_status
# Alive           731
# Dead            299
# Not Reported     38
# Name: count, dtype: int64:
#
# Column: ajcc_pathologic_t
# Distinct Values: 15
# Distribution for ajcc_pathologic_t
# ...
