# %% [markdown]
# # Scope Reducing Heatmap

# %%
import os, sys
parent_dir = os.path.abspath('..')
# the parent_dir could already be there if the kernel was not restarted,
# and we run this cell again
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# %%
import pandas as pd 
import numpy as np
import json

import panel as pn
from bdikit import APIManager

pn.extension('mathjax')
pn.extension('vega')


manager = APIManager()
manager.load_dataset('./datasets/dou.csv')
reduce_scope_plot = manager.reduce_scope()
reduce_scope_plot
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='ef5befbb-1b63-411f-a669-53f97e291742'>
#   <div id="afbb52cb-e38d-401e-8cad-48defe349f17" data-root-id="ef5befbb-1b63-411f-a669-53f97e291742" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"6b47397a-4d9c-45b0-91d7-204854dc04a9":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"ef5befbb-1b63-411f-a669-53f97e291742"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"e2a36e27-04a2-400f-896f-999e58ff6422","attributes":{"plot_id":"ef5befbb-1b63-411f-a669-53f97e291742","comm_id":"2169ca9f182b4587b6391090ab317f6d","client_comm_id":"c87b9355787e413cbedfbba7efce1c7f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"6b47397a-4d9c-45b0-91d7-204854dc04a9","roots":{"ef5befbb-1b63-411f-a669-53f97e291742":"afbb52cb-e38d-401e-8cad-48defe349f17"},"root_ids":["ef5befbb-1b63-411f-a669-53f97e291742"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|                                                                             | 0/17 [00:00<?, ?it/s]We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# 100%|████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 40.73it/s]
# Table features extracted from 17 columns
# 100%|██████████████████████████████████████████████████████████████████| 734/734 [00:34<00:00, 20.99it/s]
# Table features extracted from 734 columns
# Column(scroll=True)
#     [0] Row(styles={'background': '...})
#         [0] Select(name='Column', options=['Country', 'Histologic_Gr...], value='Country', width=220)
#         [1] Checkbox(name='Show subschema')
#         [2] MultiChoice(name='Recommendation s..., options=['germline_mutation_callin...], width=220)
#         [3] IntSlider(end=5, name='N Similar', width=220)
#         [4] EditableFloatSlider(name='Threshold', step=0.01, value=0.1, width=220)
#     [1] Column
#         [0] ParamFunction(function, _pane=Column, defer_load=False)
#     [2] Row
#         [0] Button(button_type='success', name='Accept Match')
#         [1] Button(button_type='danger', name='Decline Match')

# %%
manager.update_scope()
# Out:
# [{'Candidate column': 'Country',
#   'Top k columns': [['country_of_birth', '0.5726']]},
#  {'Candidate column': 'Histologic_Grade_FIGO',
#   'Top k columns': [['tumor_grade', '0.5817']]},
#  {'Candidate column': 'Histologic_type',
#   'Top k columns': [['history_of_tumor_type', '0.6757']]},
#  {'Candidate column': 'Path_Stage_Primary_Tumor-pT',
#   'Top k columns': [['ajcc_pathologic_stage', '0.6702']]},
#  {'Candidate column': 'Path_Stage_Reg_Lymph_Nodes-pN',
#   'Top k columns': [['uicc_clinical_stage', '0.5684']]},
#  {'Candidate column': 'Clin_Stage_Dist_Mets-cM',
#   'Top k columns': [['uicc_clinical_m', '0.7455']]},
#  {'Candidate column': 'Path_Stage_Dist_Mets-pM',
#   'Top k columns': [['uicc_clinical_m', '0.7371'],
#    ['ajcc_clinical_m', '0.7076'],
#    ['uicc_pathologic_m', '0.7069'],
#    ['ajcc_pathologic_m', '0.6833'],
#    ['ensat_clinical_m', '0.6273'],
#    ['enneking_msts_metastasis', '0.6068'],
#    ['metastasis_at_diagnosis', '0.5874'],
#    ['classification_of_tumor', '0.5729'],
#    ['masaoka_stage', '0.5534'],
#    ['uicc_clinical_stage', '0.551'],
#    ['ajcc_pathologic_stage', '0.5248'],
#    ['inrg_stage', '0.5095'],
#    ['last_known_disease_status', '0.5005'],
#    ['notes', '0.4932'],
#    ['treatment_outcome', '0.4907'],
#    ['fab_morphology_code', '0.4898'],
#    ['follow_ups', '0.4737'],
#    ['inss_stage', '0.4692'],
#    ['ensat_pathologic_stage', '0.4533'],
#    ['ajcc_clinical_stage', '0.4528']]},
#  {'Candidate column': 'tumor_Stage-Pathological',
#   'Top k columns': [['ensat_pathologic_stage', '0.8143']]},
#  {'Candidate column': 'FIGO_stage',
#   'Top k columns': [['figo_stage', '0.8703']]},
#  {'Candidate column': 'BMI',
#   'Top k columns': [['percent_stromal_cells', '0.818'],
#    ['necrosis_percent', '0.8076'],
#    ['spindle_cell_percent', '0.7874'],
#    ['recist_targeted_regions_sum', '0.7801'],
#    ['bmi', '0.7546'],
#    ['intermediate_dimension', '0.7513'],
#    ['longest_dimension', '0.721'],
#    ['average_base_quality', '0.6933'],
#    ['percent_neutrophil_infiltration', '0.6483'],
#    ['fragment_standard_deviation_length', '0.612'],
#    ['percent_lymphocyte_infiltration', '0.6003'],
#    ['size_selection_range', '0.5116'],
#    ['percent_inflam_infiltration', '0.4583'],
#    ['gross_tumor_weight', '0.458'],
#    ['weight', '0.4574'],
#    ['imaging_suv_max', '0.456'],
#    ['epithelioid_cell_percent', '0.4406'],
#    ['initial_weight', '0.4184'],
#    ['hpv_positive_type', '0.4162'],
#    ['age_at_index', '0.4117']]},
#  {'Candidate column': 'Age',
#   'Top k columns': [['age_at_onset', '0.8855'],
#    ['age_at_last_exposure', '0.8768'],
#    ['age_at_index', '0.8745'],
#    ['age_at_diagnosis', '0.8623'],
#    ['relationship_age_at_diagnosis', '0.8441'],
#    ['undescended_testis_corrected_age', '0.7382'],
#    ['age_is_obfuscated', '0.644'],
#    ['pack_years_smoked', '0.6387'],
#    ['menopause_status', '0.6157'],
#    ['days_to_birth', '0.596'],
#    ['epithelioid_cell_percent', '0.5842'],
#    ['tobacco_smoking_onset_year', '0.5802'],
#    ['demographics', '0.569'],
#    ['year_of_death', '0.5676'],
#    ['tobacco_smoking_quit_year', '0.5491'],
#    ['fev1_fvc_pre_bronch_percent', '0.5471'],
#    ['weight', '0.5348'],
#    ['fev1_fvc_post_bronch_percent', '0.514'],
#    ['years_smoked', '0.5107'],
#    ['percent_necrosis', '0.5102']]},
#  {'Candidate column': 'Race',
#   'Top k columns': [['ethnicity', '0.7531'],
#    ['race', '0.7397'],
#    ['eye_color', '0.4766'],
#    ['channel', '0.425'],
#    ['variant_origin', '0.4006'],
#    ['demographics', '0.3645'],
#    ['supratentorial_localization', '0.3533'],
#    ['somatic_annotation_workflows', '0.348'],
#    ['stain_type', '0.3314'],
#    ['fab_morphology_code', '0.329'],
#    ['melanoma_known_primary', '0.3175'],
#    ['histone_variant', '0.3156'],
#    ['radon_exposure', '0.3118'],
#    ['measurement_type', '0.307'],
#    ['histone_family', '0.2993'],
#    ['country_of_birth', '0.2875'],
#    ['country_of_residence_at_enrollment', '0.2843'],
#    ['somatic_aggregation_workflows', '0.2837'],
#    ['somatic_mutation_calling_workflows', '0.2808'],
#    ['exposure_source', '0.278']]},
#  {'Candidate column': 'Ethnicity',
#   'Top k columns': [['ethnicity', '0.8505'],
#    ['race', '0.6468'],
#    ['variant_origin', '0.4661'],
#    ['demographics', '0.3661'],
#    ['eye_color', '0.3564'],
#    ['measurement_type', '0.3227'],
#    ['channel', '0.3153'],
#    ['country_of_birth', '0.3073'],
#    ['methylation_array_harmonization_workflows', '0.2998'],
#    ['country_of_residence_at_enrollment', '0.2993'],
#    ['fab_morphology_code', '0.2927'],
#    ['stain_type', '0.2794'],
#    ['education_level', '0.2781'],
#    ['mean_coverage', '0.2714'],
#    ['alcohol_type', '0.2648'],
#    ['exposure_source', '0.2624'],
#    ['somatic_annotation_workflows', '0.2578'],
#    ['analyte_type', '0.2569'],
#    ['gender', '0.2544'],
#    ['wgs_coverage', '0.2528']]},
#  {'Candidate column': 'Gender',
#   'Top k columns': [['gender', '0.908'],
#    ['relationship_gender', '0.8735'],
#    ['pregnant_at_diagnosis', '0.5085'],
#    ['menopause_status', '0.5046'],
#    ['hormonal_contraceptive_type', '0.4781'],
#    ['pregnancy_outcome', '0.4511'],
#    ['tumor_shape', '0.439'],
#    ['marital_status', '0.4323'],
#    ['variant_origin', '0.4315'],
#    ['demographics', '0.4067'],
#    ['tumor_confined_to_organ_of_origin', '0.389'],
#    ['analyte_type', '0.3619'],
#    ['undescended_testis_corrected', '0.3616'],
#    ['relationship_age_at_diagnosis', '0.3613'],
#    ['weeks_gestation_at_birth', '0.3573'],
#    ['relationship_type', '0.3565'],
#    ['tumor_focality', '0.3563'],
#    ['undescended_testis_history_laterality', '0.3474'],
#    ['undescended_testis_corrected_age', '0.344'],
#    ['ovarian_surface_involvement', '0.3385']]},
#  {'Candidate column': 'Tumor_Site',
#   'Top k columns': [['margins_involved_site', '0.6137'],
#    ['tumor_depth_descriptor', '0.5781'],
#    ['max_tumor_bulk_site', '0.5583'],
#    ['supratentorial_localization', '0.5446'],
#    ['enneking_msts_tumor_site', '0.5399'],
#    ['tumor_level_prostate', '0.5308'],
#    ['primary_site', '0.5265'],
#    ['morphologic_architectural_pattern', '0.52'],
#    ['tumor_shape', '0.4893'],
#    ['biospecimen_type', '0.4642'],
#    ['tissue_or_organ_of_origin', '0.4573'],
#    ['tumor_focality', '0.4343'],
#    ['site_of_resection_or_biopsy', '0.434'],
#    ['treatment_anatomic_site', '0.4275'],
#    ['ovarian_surface_involvement', '0.3998'],
#    ['lymph_node_involved_site', '0.3911'],
#    ['history_of_tumor', '0.39'],
#    ['imaging_type', '0.3897'],
#    ['metastasis_at_diagnosis', '0.3885'],
#    ['sites_of_involvement', '0.3876']]},
#  {'Candidate column': 'Tumor_Focality',
#   'Top k columns': [['tumor_focality', '0.808'],
#    ['tumor_shape', '0.5626'],
#    ['tumor_depth_descriptor', '0.5311'],
#    ['enneking_msts_tumor_site', '0.4829'],
#    ['biospecimen_type', '0.4809'],
#    ['tissue_type', '0.4783'],
#    ['wilms_tumor_histologic_subtype', '0.4597'],
#    ['residual_tumor_measurement', '0.4544'],
#    ['non_nodal_tumor_deposits', '0.451'],
#    ['tumor_infiltrating_macrophages', '0.4464'],
#    ['specimen_type', '0.443'],
#    ['extranodal_extension', '0.4366'],
#    ['measurement_unit', '0.4319'],
#    ['columnar_mucosa_present', '0.4153'],
#    ['distance_normal_to_tumor', '0.4077'],
#    ['morphologic_architectural_pattern', '0.3949'],
#    ['vascular_invasion_type', '0.3896'],
#    ['residual_tumor', '0.3751'],
#    ['enneking_msts_metastasis', '0.3703'],
#    ['ovarian_specimen_status', '0.3582']]},
#  {'Candidate column': 'Tumor_Size_cm',
#   'Top k columns': [['shortest_dimension', '0.7575'],
#    ['size_extraocular_nodule', '0.7416'],
#    ['tumor_width_measurement', '0.7034'],
#    ['tumor_depth_measurement', '0.6989'],
#    ['tumor_thickness', '0.6506'],
#    ['analyte_quantity', '0.6418'],
#    ['average_insert_size', '0.6362'],
#    ['tumor_largest_dimension_diameter', '0.5736'],
#    ['mitotic_total_area', '0.5635'],
#    ['rin', '0.5578'],
#    ['size_selection_range', '0.5574'],
#    ['imaging_suv', '0.5519'],
#    ['tumor_infiltrating_macrophages', '0.5417'],
#    ['breslow_thickness', '0.5358'],
#    ['circumferential_resection_margin', '0.5312'],
#    ['body_surface_area', '0.5154'],
#    ['workflow_version', '0.5089'],
#    ['mean_coverage', '0.5042'],
#    ['tumor_depth', '0.4949'],
#    ['tumor_depth_descriptor', '0.4846']]}]

# %%
column_mappings = manager.map_columns()
# Out:
#                   Original Column              Target Column
# 0                         Country           country_of_birth
# 1           Histologic_Grade_FIGO                tumor_grade
# 2                 Histologic_type      history_of_tumor_type
# 3     Path_Stage_Primary_Tumor-pT      ajcc_pathologic_stage
# 4   Path_Stage_Reg_Lymph_Nodes-pN        uicc_clinical_stage
# 5         Clin_Stage_Dist_Mets-cM            uicc_clinical_m
# 6         Path_Stage_Dist_Mets-pM  last_known_disease_status
# 7        tumor_Stage-Pathological     ensat_pathologic_stage
# 8                      FIGO_stage                 figo_stage
# 9                             BMI               age_at_index
# 10                            Age                     weight
# 11                           Race                       race
# 12                      Ethnicity                  ethnicity
# 13                         Gender                     gender
# 14                     Tumor_Site                tumor_shape
# 15                 Tumor_Focality             tumor_focality
# 16                  Tumor_Size_cm                tumor_depth

# %%
value_mappings = manager.map_values('LLMAlgorithm')
# Out:
# Column Histologic_Grade_FIGO:
#   Current Value Target Value  Similarity
# 0  FIGO grade 1           G1         1.0
# 1  FIGO grade 2           G2         1.0
# 2           nan      Unknown         1.0
# 3  FIGO grade 3           G3         1.0
# Column Histologic_type:
#     Current Value                        Target Value  Similarity
# 0    Endometrioid                   Colorectal Cancer         0.1
# 1  Carcinosarcoma                   Colorectal Cancer         0.1
# 2          Serous                  Lower Grade Glioma         0.1
# 3      Clear cell  Phenochromocytoma or Paraganglioma         0.5
# Column Path_Stage_Primary_Tumor-pT:
#       Current Value Target Value  Similarity
# 0    pT1a (FIGO IA)     Stage IA         1.0
# 1               nan      Unknown         1.0
# 2  pT3a (FIGO IIIA)   Stage IIIA         1.0
# 3      pT1 (FIGO I)     Stage IA         1.0
# 4    pT1b (FIGO IB)     Stage IB         1.0
# 5     pT2 (FIGO II)     Stage II         1.0
# 6  pT3b (FIGO IIIB)   Stage IIIB         1.0
# Column Path_Stage_Reg_Lymph_Nodes-pN:
#       Current Value Target Value  Similarity
# 0               pN0      Unknown         1.0
# 1               pNX      Stage X         1.0
# 2               nan      Unknown         1.0
# 3  pN2 (FIGO IIIC2)  Stage IIIC2         1.0
# 4  pN1 (FIGO IIIC1)  Stage IIIC1         1.0
# Column Clin_Stage_Dist_Mets-cM:
#         Current Value Target Value  Similarity
# 0                 cM0           M0         1.0
# 1                 nan      Unknown         1.0
# 2  Staging Incomplete      Unknown         0.9
# 3                 cM1           M1         1.0
# Column Path_Stage_Dist_Mets-pM:
#                                   Current Value          Target Value  \
# 0                            Staging Incomplete  Unknown tumor status
# 1                                           nan          not reported
# 2  No pathologic evidence of distant metastasis            Tumor free
# 3                                           pM1            With tumor
#
#    Similarity
# 0         0.9
# 1         1.0
# 2         0.9
# 3         0.6
# Column tumor_Stage-Pathological:
#   Current Value Target Value  Similarity
# 0       Stage I      Stage I         1.0
# 1      Stage IV     Stage IV         1.0
# 2           nan      Stage I         0.0
# 3     Stage III    Stage III         1.0
# 4      Stage II     Stage II         1.0
# Column FIGO_stage:
#   Current Value Target Value  Similarity
# 0            IA     Stage IA         1.0
# 1           nan      Unknown         1.0
# 2          IIIA   Stage IIIA         1.0
# 3         IIIC2  Stage IIIC2         1.0
# 4            IB     Stage IB         1.0
# 5            II     Stage II         1.0
# 6         IIIC1  Stage IIIC1         1.0
# 7           IVB    Stage IVB         1.0
# 8          IIIB   Stage IIIB         1.0
# Column Race:
#                Current Value               Target Value  Similarity
# 0                      White                      white         1.0
# 1                        nan               not reported         1.0
# 2                      Asian                      asian         1.0
# 3               Not Reported               not reported         1.0
# 4  Black or African American  black or african american         1.0
# Column Gender:
#   Current Value Target Value  Similarity
# 0        Female       female         1.0
# 1           nan      unknown         1.0
# Column Tumor_Site:
#            Current Value Target Value  Similarity
# 0   Anterior endometrium      Unknown         1.0
# 1  Posterior endometrium      Unknown         1.0
# 2         Other, specify      Unknown         1.0
# 3                    nan      Unknown         1.0
# Column Tumor_Focality:
#   Current Value Target Value  Similarity
# 0      Unifocal     Unifocal         1.0
# 1           nan      Unknown         1.0
# 2    Multifocal   Multifocal         1.0
# Column Country:
#    Current Value   Target Value Similarity
# 0  United States  United States          1
# 1  Other_specify    Afghanistan          0
# 2        Ukraine        Ukraine        1.0
# 3         Poland         Poland        1.0
# 4            nan              -          -
# Column Ethnicity:
#             Current Value            Target Value Similarity
# 0  Not-Hispanic or Latino  not hispanic or latino        1.0
# 1                     nan  not hispanic or latino        0.5
# 2      Hispanic or Latino      hispanic or latino        1.0
# 3            Not reported                       -          -

# %% [markdown]
# # Heatmap Manager Object

# %%
from bdikit.visualization.scope_reducing import SRHeatMapManager

heatmap_manager = SRHeatMapManager(manager.dataset)
# heatmap_manager._write_json(manager.reduced_scope)
heatmap_manager.get_heatmap()
heatmap_manager.plot_heatmap()
