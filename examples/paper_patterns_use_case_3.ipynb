# %% [markdown]
# # Use Case 3: Using AI Agents to Interact with BDI-Kit

# %% [markdown]
# This example showcases the **BDI-Kit conversational Streamlit interface** for interactive data harmonization using an open-source LLM.
#
# ---
#
# ## 🚀 Run the Chatbot
#
# Launch the Streamlit chatbot:
#
# ```bash
# bdikit-chatbot --llm deepinfra/openai/gpt-oss-120b
# ```
#
# You will need the following dataset:
#
# - `datasets/clark.csv`
#
# ---
#
# ## 💬 Workflow Conversation
#
# 👤 **Harmonize the schema of the dataset located at**  `/datasets/clark.csv`  **to the GDC schema using bdi-kit**
#
# 🤖 ...
#
#
# 👤 **Can you check if there is a better match for** `"Age"`**?**
#
# 🤖 ...
#
#
# 👤 **From the available methods, which one is most suitable for matching the values of the numeric attributes?**
#
# 🤖 ...
#
#
# 👤 **Use the** `llm_numeric` **method to match the values of the numeric attributes**
#
# 🤖 ...
