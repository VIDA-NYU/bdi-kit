# %% [markdown]
# # Scenario 2: AI-Assisted Harmonization

# %% [markdown]
# This example demonstrates the **BDI-Kit conversational Streamlit interface** for interactive data harmonization.
#
# ---
#
# ## 🚀 Run the Chatbot
#
# Launch the Streamlit chatbot:
#
# ```bash
# bdikit-chatbot --llm openai/gpt-5-mini
# ```
#
# You will need the following dataset:
#
# - `datasets/cao_sample.csv`
#
# ---
#
# ## 💬 Workflow Conversation
#
# 👤 **Harmonize the schema of the dataset located at**  `/datasets/cao_sample.csv`  **to the GDC standard using BDI-Kit**
#
# 🤖 ...
#
#
# 👤 **Why did you update the match for `pathologic_staging_regional_lymph_nodes_pn`?**
#
# 🤖 ...
#
#
# 👤 **Find the value matches for the pair `cause_of_death` and `cause_of_death`**
#
# 🤖 ...
#
#
# 👤 **Values related to "Null" should only be mapped to "Unknown"**
#
# 🤖 ...
