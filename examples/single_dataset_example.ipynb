# %% [markdown]
# # Data Integration with BDI

# %%
from bdi import APIManager

# %%
manager = APIManager()

# %% [markdown]
# ## Dataset Loading

# %%
dataset_path =  './datasets/dou.csv'
dataset = manager.load_dataset(dataset_path)
dataset
# Out:
#       idx Proteomics_Participant_ID Case_excluded  Proteomics_TMT_batch  \
# 0    S001                 C3L-00006            No                     2
# 1    S002                 C3L-00008            No                     4
# 2    S003                 C3L-00032            No                     1
# 3    S004                 C3L-00084           Yes                     3
# 4    S005                 C3L-00090            No                     3
# ..    ...                       ...           ...                   ...
# 148  S149                      NX14            No                     5
# 149  S150                      NX15            No                     5
# 150  S151                      NX16            No                     5
# 151  S152                      NX17            No                     5
# 152  S153                      NX18            No                     5
#
#      Proteomics_TMT_plex Proteomics_TMT_channel  \
# 0                      5                   128N
# 1                     16                   130N
# 2                      2                    131
# 3                     11                   129N
# 4                     12                   129C
# ..                   ...                    ...
# 148                   17                   128C
# 149                   17                    131
# 150                   17                   129C
# 151                   17                   127C
# 152                   17                   130N
#
#                Proteomics_Parent_Sample_IDs  \
# 0                              C3L-00006-01
# 1                              C3L-00008-01
# 2                              C3L-00032-01
# 3                              C3L-00084-01
# 4                              C3L-00090-01
# ..                                      ...
# 148               C3N-03699-01,C3N-03699-02
# 149                            C3N-03700-01
# 150  C3N-03701-01,C3N-03701-02,C3N-03701-03
# 151  C3N-03706-01,C3N-03706-02,C3N-03706-03
# 152  C3N-03708-01,C3N-03708-02,C3N-03708-03
#
#                                  Proteomics_Aliquot_ID  \
# 0                                        CPT0001460012
# 1                                        CPT0001300009
# 2                                        CPT0001420009
# 3                                        CPT0000820012
# 4                                        CPT0001140003
# ..                                                 ...
# 148  CPT0230130002,CPT0230130003,CPT0230130004,CPT0...
# 149          CPT0230190002,CPT0230190003,CPT0230190004
# 150  CPT0230250002,CPT0230260002,CPT0230270002,CPT0...
# 151  CPT0230400002,CPT0230400003,CPT0230400004,CPT0...
# 152  CPT0230460002,CPT0230460003,CPT0230460004,CPT0...
#
#     Proteomics_Tumor_Normal Proteomics_OCT  ... RNAseq_R1_sample_type  \
# 0                     Tumor             No  ...                 Tumor
# 1                     Tumor             No  ...                 Tumor
# 2                     Tumor             No  ...                 Tumor
# 3                     Tumor             No  ...                 Tumor
# 4                     Tumor             No  ...                 Tumor
# ..                      ...            ...  ...                   ...
# 148         Enriched_normal             No  ...                   NaN
# 149         Enriched_normal             No  ...                   NaN
# 150         Enriched_normal             No  ...                   NaN
# 151         Enriched_normal             No  ...                   NaN
# 152         Enriched_normal             No  ...                   NaN
#
#                                     RNAseq_R1_filename  \
# 0    170802_UNC31-K00269_0072_AHK3GVBBXX_TAGCTT_S17...
# 1    170802_UNC31-K00269_0072_AHK3GVBBXX_GGCTAC_S22...
# 2    170802_UNC31-K00269_0072_AHK3GVBBXX_GTCCGC_S18...
# 3    170818_UNC32-K00270_0050_AHL2FHBBXX_ATCACG_S5_...
# 4    170802_UNC31-K00269_0072_AHK3GVBBXX_GAGTGG_S10...
# ..                                                 ...
# 148                                                NaN
# 149                                                NaN
# 150                                                NaN
# 151                                                NaN
# 152                                                NaN
#
#                            RNAseq_R1_UUID RNAseq_R2_sample_type  \
# 0    8a1efc47-1c29-417f-a425-cdbd09565dcb                 Tumor
# 1    555725e8-cba5-4676-9b0a-80100cbf9f47                 Tumor
# 2    9ae968f3-691d-4db3-9977-1ab3e5af9085                 Tumor
# 3    b0a7cdf2-2ad8-4442-91b0-548ea4975554                 Tumor
# 4    8ce5618d-9ff6-40f9-aeea-8d8e1633ae38                 Tumor
# ..                                    ...                   ...
# 148                                   NaN                   NaN
# 149                                   NaN                   NaN
# 150                                   NaN                   NaN
# 151                                   NaN                   NaN
# 152                                   NaN                   NaN
#
#                                     RNAseq_R2_filename  \
# 0    170802_UNC31-K00269_0072_AHK3GVBBXX_TAGCTT_S17...
# 1    170802_UNC31-K00269_0072_AHK3GVBBXX_GGCTAC_S22...
# 2    170802_UNC31-K00269_0072_AHK3GVBBXX_GTCCGC_S18...
# 3    170818_UNC32-K00270_0050_AHL2FHBBXX_ATCACG_S5_...
# 4    170802_UNC31-K00269_0072_AHK3GVBBXX_GAGTGG_S10...
# ..                                                 ...
# 148                                                NaN
# 149                                                NaN
# 150                                                NaN
# 151                                                NaN
# 152                                                NaN
#
#                            RNAseq_R2_UUID miRNAseq_sample_type  \
# 0    8c3fe9b7-7acd-4867-8d9c-a8e5d1516eda                Tumor
# 1    15235b12-b67a-4678-acc4-ed03d642bd5e                Tumor
# 2    423b6b09-02aa-4f47-9241-f75c1dad1161                Tumor
# 3    c83987a5-1c13-4af4-b46c-218fe5f60c34                  NaN
# 4    06d3fd4a-a623-4146-8500-4f1f17235253                Tumor
# ..                                    ...                  ...
# 148                                   NaN                  NaN
# 149                                   NaN                  NaN
# 150                                   NaN                  NaN
# 151                                   NaN                  NaN
# 152                                   NaN                  NaN
#
#                             miRNAseq_UUID Methylation_available  \
# 0    37bcba98-1094-459e-83ae-c23a602416fb                   YES
# 1    492b50d8-ec35-46e7-a65d-06512aaee394                   YES
# 2    1794ff56-db2d-4d1a-8758-cab7fe3d98c1                   YES
# 3                                     NaN                   YES
# 4    a6524c2d-d7dd-4629-980e-b45dbdc92c49                   YES
# ..                                    ...                   ...
# 148                                   NaN                   NaN
# 149                                   NaN                   NaN
# 150                                   NaN                   NaN
# 151                                   NaN                   NaN
# 152                                   NaN                   NaN
#
#     Methylation_quality
# 0                  PASS
# 1                  PASS
# 2                  PASS
# 3                  PASS
# 4                  PASS
# ..                  ...
# 148                 NaN
# 149                 NaN
# 150                 NaN
# 151                 NaN
# 152                 NaN
#
# [153 rows x 179 columns]

# %%
manager.global_table

# %% [markdown]
# ## Column Mapping

# %%
manager.reduce_scope()
column_mappings = manager.map_columns()
column_mappings
# Out:
# {'Gender': 'gender',
#  'Race': 'race',
#  'Ethnicity': 'ethnicity',
#  'Histologic_Grade_FIGO': 'tumor_grade',
#  'tumor_Stage-Pathological': 'ajcc_pathologic_stage',
#  'Path_Stage_Reg_Lymph_Nodes-pN': 'ajcc_pathologic_n',
#  'Path_Stage_Primary_Tumor-pT': 'ajcc_pathologic_t',
#  'Tumor_Focality': 'tumor_focality',
#  'Tumor_Site': 'tissue_or_organ_of_origin',
#  'Histologic_type': 'morphology'}

# %% [markdown]
# ## Value Mapping

# %%
# manager.map_values()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 manager.map_values()
#
# File ~/nyu-code/askem-arpa-h-project/bdi/api.py:43, in APIManager.map_values(self)
#      41 self.global_table = get_gdc_data(self.column_mappings.values())
#      42 self.value_manager = ValueMappingManager(self.dataset, self.column_mappings, self.global_table )
# ---> 43 self.value_mappings = self.value_manager.map()
#      45 return self.value_mappings
#
# File ~/nyu-code/askem-arpa-h-project/bdi/mapping_recommendation/value_mapping_manager.py:33, in ValueMappingManager.map(self, include_unmatches)
#      31 def map(self, include_unmatches=True):
#      32     if self.mapping_results is None:
# ---> 33         self._match_values()
#      35     sorted_results = sorted(self.mapping_results.items(), key=lambda x: x[1]['coverage'], reverse=True)
#      37     for column_name, _ in sorted_results:
#
# File ~/nyu-code/askem-arpa-h-project/bdi/mapping_recommendation/value_mapping_manager.py:58, in ValueMappingManager._match_values(self)
#      54 current_values_dict = {str(x).strip().lower(): str(x).strip() for x in self.dataset[current_column].unique()}
#      55 self.mapping_results[current_column] = {'matches': None, 'coverage':  None,
#      56                                         'unique_values': None, 'unmatch_values': None}
# ---> 58 matches_lowercase = self.matcher_method.match(list(current_values_dict.keys()), list(target_values_dict.keys()))
#      59 matches = []
#      61 for current_value, target_value, similarity in matches_lowercase:
#
# File ~/nyu-code/askem-arpa-h-project/bdi/mapping_algorithms/value_mapping/algorithms.py:48, in EditMatcher.match(self, current_values, target_values, threshold)
#      47 def match(self, current_values, target_values, threshold=0.8):
# ---> 48     matches = super().match(current_values, target_values, threshold)
#      50     return matches
#
# File ~/nyu-code/askem-arpa-h-project/bdi/mapping_algorithms/value_mapping/algorithms.py:14, in BaseMatcher.match(self, current_values, target_values, threshold)
#      13 def match(self, current_values, target_values, threshold=0.8):
# ---> 14     self.model.match(current_values, target_values)
#      15     match_results = self.model.get_matches()
#      16     match_results.sort_values(by='Similarity', ascending=False, inplace=True)
#
# File ~/miniconda3/envs/arpah/lib/python3.12/site-packages/polyfuzz/polyfuzz.py:143, in PolyFuzz.match(self, from_list, to_list, top_n)
#     141 # Custom models
#     142 elif isinstance(self.method, BaseMatcher):
# --> 143     self.matches = {self.method.model_id: self.method.match(from_list, to_list)}
#     144     logging.info(f"Ran model with model id = {self.method.model_id}")
#     146 # Multiple custom models
#
# File ~/miniconda3/envs/arpah/lib/python3.12/site-packages/polyfuzz/models/_distance.py:77, in EditDistance.match(self, from_list, to_list, **kwargs)
#      74 else:
#      75     expected_iterations = len(from_list)
# ---> 77 matches = Parallel(n_jobs=self.n_jobs)(delayed(self._calculate_edit_distance)
#      78                                        (from_string, to_list)
#      79                                        for from_string in tqdm(from_list, total=expected_iterations,
#      80                                                                disable=True))
#      81 matches = pd.DataFrame(matches, columns=['From', "To", "Similarity"])
#      83 if self.normalize:
#
# File ~/miniconda3/envs/arpah/lib/python3.12/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/miniconda3/envs/arpah/lib/python3.12/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/miniconda3/envs/arpah/lib/python3.12/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:
