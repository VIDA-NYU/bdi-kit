# %% [markdown]
# ## Data Harmonization Between Two Datasets with `bdikit`

# %% [markdown]
# Data harmonization is the process of integrating and aligning data from different sources into a consistent format to ensure compatibility and interoperability across data analyses and systems. `bdikit` is a library the helps with key data harmonization steps:
# - *Schema Mapping*: In this step, data from various sources are mapped to a unified schema or model. This involves identifying equivalent table columns and establishing relationships between disparate datasets.
# - *Value Mapping (Data Standardization)*: This step involves converting data into a common format or structure, using consistent naming conventions, units, and coding systems to ensure uniformity.
#
# In this example, we describe how `bdikit` can be used to harmonize datasets from two papers:
# - Dou et al. 2020, Proteogenomic Characterization of Endometrial Carcinoma. https://pubmed.ncbi.nlm.nih.gov/32059776/ (CPTAC Discovery)
# - Dou et al. 2023, Proteogenomic insights suggest druggable pathways in endometrial carcinoma. https://pubmed.ncbi.nlm.nih.gov/37567170/ (CPTAC Confirmatory)

# %% [markdown]
# #### Loading the data

# %% [markdown]
# First, import the `bdikit` library and other libraries.

# %%
import bdikit as bdi
import pandas as pd
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f84500c5-86f2-403c-a374-ccecf418165a'>
#   <div id="ad0fc754-728b-4f33-89af-a379e413ab30" data-root-id="f84500c5-86f2-403c-a374-ccecf418165a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"fa5b8bcd-9d11-448a-8882-9f25247bd9c1":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"f84500c5-86f2-403c-a374-ccecf418165a"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"2f512100-70f4-40b8-9a76-26901bf76a3e","attributes":{"plot_id":"f84500c5-86f2-403c-a374-ccecf418165a","comm_id":"2ce5b6ef3bea4bb98ef2ff90e857da2d","client_comm_id":"74e2720c87314b2e90b23c19fa3eef65"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"fa5b8bcd-9d11-448a-8882-9f25247bd9c1","roots":{"f84500c5-86f2-403c-a374-ccecf418165a":"ad0fc754-728b-4f33-89af-a379e413ab30"},"root_ids":["f84500c5-86f2-403c-a374-ccecf418165a"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# Next, we load our source data using Pandas and select some columns we are interested in.

# %%
df_source = pd.read_csv("./datasets/Dou-ucec-discovery.csv")
df_source.head(5)
# Out:
#     idx Proteomics_Participant_ID Case_excluded  Proteomics_TMT_batch  \
# 0  S001                 C3L-00006            No                     2
# 1  S002                 C3L-00008            No                     4
# 2  S003                 C3L-00032            No                     1
# 3  S004                 C3L-00084           Yes                     3
# 4  S005                 C3L-00090            No                     3
#
#    Proteomics_TMT_plex Proteomics_TMT_channel Proteomics_Parent_Sample_IDs  \
# 0                    5                   128N                 C3L-00006-01
# 1                   16                   130N                 C3L-00008-01
# 2                    2                    131                 C3L-00032-01
# 3                   11                   129N                 C3L-00084-01
# 4                   12                   129C                 C3L-00090-01
#
#   Proteomics_Aliquot_ID Proteomics_Tumor_Normal Proteomics_OCT  ...  \
# 0         CPT0001460012                   Tumor             No  ...
# 1         CPT0001300009                   Tumor             No  ...
# 2         CPT0001420009                   Tumor             No  ...
# 3         CPT0000820012                   Tumor             No  ...
# 4         CPT0001140003                   Tumor             No  ...
#
#   RNAseq_R1_sample_type                                 RNAseq_R1_filename  \
# 0                 Tumor  170802_UNC31-K00269_0072_AHK3GVBBXX_TAGCTT_S17...
# 1                 Tumor  170802_UNC31-K00269_0072_AHK3GVBBXX_GGCTAC_S22...
# 2                 Tumor  170802_UNC31-K00269_0072_AHK3GVBBXX_GTCCGC_S18...
# 3                 Tumor  170818_UNC32-K00270_0050_AHL2FHBBXX_ATCACG_S5_...
# 4                 Tumor  170802_UNC31-K00269_0072_AHK3GVBBXX_GAGTGG_S10...
#
#                          RNAseq_R1_UUID RNAseq_R2_sample_type  \
# 0  8a1efc47-1c29-417f-a425-cdbd09565dcb                 Tumor
# 1  555725e8-cba5-4676-9b0a-80100cbf9f47                 Tumor
# 2  9ae968f3-691d-4db3-9977-1ab3e5af9085                 Tumor
# 3  b0a7cdf2-2ad8-4442-91b0-548ea4975554                 Tumor
# 4  8ce5618d-9ff6-40f9-aeea-8d8e1633ae38                 Tumor
#
#                                   RNAseq_R2_filename  \
# 0  170802_UNC31-K00269_0072_AHK3GVBBXX_TAGCTT_S17...
# 1  170802_UNC31-K00269_0072_AHK3GVBBXX_GGCTAC_S22...
# 2  170802_UNC31-K00269_0072_AHK3GVBBXX_GTCCGC_S18...
# 3  170818_UNC32-K00270_0050_AHL2FHBBXX_ATCACG_S5_...
# 4  170802_UNC31-K00269_0072_AHK3GVBBXX_GAGTGG_S10...
#
#                          RNAseq_R2_UUID miRNAseq_sample_type  \
# 0  8c3fe9b7-7acd-4867-8d9c-a8e5d1516eda                Tumor
# 1  15235b12-b67a-4678-acc4-ed03d642bd5e                Tumor
# 2  423b6b09-02aa-4f47-9241-f75c1dad1161                Tumor
# 3  c83987a5-1c13-4af4-b46c-218fe5f60c34                  NaN
# 4  06d3fd4a-a623-4146-8500-4f1f17235253                Tumor
#
#                           miRNAseq_UUID Methylation_available  \
# 0  37bcba98-1094-459e-83ae-c23a602416fb                   YES
# 1  492b50d8-ec35-46e7-a65d-06512aaee394                   YES
# 2  1794ff56-db2d-4d1a-8758-cab7fe3d98c1                   YES
# 3                                   NaN                   YES
# 4  a6524c2d-d7dd-4629-980e-b45dbdc92c49                   YES
#
#   Methylation_quality
# 0                PASS
# 1                PASS
# 2                PASS
# 3                PASS
# 4                PASS
#
# [5 rows x 179 columns]

# %% [markdown]
# Then, we load the target dataset:

# %%
df_target = pd.read_csv("./datasets/Dou-ucec-confirmatory.csv")
df_target.head(5)
# Out:
#          Idx    Case_id Case_excluded Batch  Plex ReporterName     Aliquot_ID  \
# 0  C3L-00086  C3L-00086            No    b4  16.0         128N  CPT0092460003
# 1  C3L-00898  C3L-00898            No    b4  14.0         128C  CPT0172200008
# 2  C3L-00943  C3L-00943            No    b4  15.0         130C  CPT0086090003
# 3  C3L-01064  C3L-01064            No    b3   9.0         129N  CPT0113430004
# 4  C3L-01277  C3L-01277            No    b4  13.0         130N  CPT0093170003
#
#    Group Discovery_study Age  ... Follow-up_additional_surgery_for_new_tumor  \
# 0  Tumor              No  56  ...                            n/a|No|No|No|No
# 1  Tumor              No  54  ...                            n/a|n/a|n/a|n/a
# 2  Tumor              No  63  ...                                n/a|n/a|n/a
# 3  Tumor              No  54  ...                                No|No|No|No
# 4  Tumor              No  61  ...                                  n/a|No|No
#
#   Follow-up_additional_treatment_radiation_therapy_for_new_tumor  \
# 0                                n/a|Yes|Yes|Yes|Yes
# 1                                    n/a|n/a|n/a|n/a
# 2                                        n/a|n/a|n/a
# 3                                       No|Yes|No|No
# 4                                         n/a|No|Yes
#
#   Follow-up_additional_treatment_pharmaceutical_therapy_for_new_tumor  \
# 0                                n/a|Yes|Yes|Yes|Yes
# 1                                    n/a|n/a|n/a|n/a
# 2                                        n/a|n/a|n/a
# 3                                    Yes|Yes|Yes|Yes
# 4                                         n/a|Yes|No
#
#    Follow-up_additional_treatment_immuno_for_new_tumor  \
# 0                                    n/a|No|No|No|No
# 1                                    n/a|n/a|n/a|n/a
# 2                                        n/a|n/a|n/a
# 3                                        No|No|No|No
# 4                                          n/a|No|No
#
#    Follow-up_days_from_date_of_collection_to_date_of_last_contact  \
# 0                      330.0|701.0|1046.0|1436.0|n/a
# 1                           396.0|746.0|982.0|1600.0
# 2                                 237.0|693.0|1039.0
# 3                          453.0|726.0|1062.0|1447.0
# 4                                  351.0|713.0|967.0
#
#            Follow-up_cause_of_death  \
# 0  n/a|n/a|n/a|n/a|Breast Carcinoma
# 1                   n/a|n/a|n/a|n/a
# 2                       n/a|n/a|n/a
# 3                   n/a|n/a|n/a|n/a
# 4                       n/a|n/a|n/a
#
#    Follow-up_days_from_date_of_initial_pathologic_diagnosis_to_date_of_death  \
# 0                             n/a|n/a|n/a|n/a|1578.0
# 1                                    n/a|n/a|n/a|n/a
# 2                                        n/a|n/a|n/a
# 3                                    n/a|n/a|n/a|n/a
# 4                                        n/a|n/a|n/a
#
#   Follow-up_days_from_date_of_initial_pathologic_diagnosis_to_date_of_additional_surgery_for_new_tumor  \
# 0                                n/a|n/a|n/a|n/a|n/a
# 1                                    n/a|n/a|n/a|n/a
# 2                                        n/a|n/a|n/a
# 3                                    n/a|n/a|n/a|n/a
# 4                                        n/a|n/a|n/a
#
#   Follow-up_procedure_type_of_new_tumor  \
# 0                   n/a|n/a|n/a|n/a|n/a
# 1                       n/a|n/a|n/a|n/a
# 2                           n/a|n/a|n/a
# 3                       n/a|n/a|n/a|n/a
# 4                           n/a|n/a|n/a
#
#   Follow-up_residual_tumor_after_surgery_for_new_tumor
# 0                                n/a|n/a|n/a|n/a|n/a
# 1                                    n/a|n/a|n/a|n/a
# 2                                        n/a|n/a|n/a
# 3                                    n/a|n/a|n/a|n/a
# 4                                        n/a|n/a|n/a
#
# [5 rows x 213 columns]

# %% [markdown]
# For this demo, we are going to focus on a subset of the columns.

# %%
column_names = [
    "Proteomics_Participant_ID",
    "Case_excluded",
    "Proteomics_TMT_channel",
    "Proteomics_Aliquot_ID",
    "Proteomics_Tumor_Normal",
    "Country",
    "Histologic_type",
    "Path_Stage_Primary_Tumor-pT",
    "Path_Stage_Reg_Lymph_Nodes-pN",
    "Clin_Stage_Dist_Mets-cM",
    "tumor_Stage-Pathological",
    "BMI",
    "Age",
    "Diabetes",
    "Race",
    "Ethnicity",
    "Gender",
    "Tumor_Site",
    "Tumor_Site_Other",
    "Tumor_Focality",
    "Tumor_Size_cm",
    "Estrogen_Receptor",
    "Progesterone_Receptor",
    "MLH1",
    "PMS2",
    "p53",
    "MLH1_Promoter_Hypermethylation",
    "Num_full_term_pregnancies",
    "ESTIMATE_StromalScore",
    "ESTIMATE_ESTIMATEScore",
    "CNV_class",
    "MSI_status",
    "POLE_subtype",
    "Genomics_subtype",
]
df_source = df_source[column_names]
df_source.head(5)
# Out:
#   Proteomics_Participant_ID Case_excluded Proteomics_TMT_channel  \
# 0                 C3L-00006            No                   128N
# 1                 C3L-00008            No                   130N
# 2                 C3L-00032            No                    131
# 3                 C3L-00084           Yes                   129N
# 4                 C3L-00090            No                   129C
#
#   Proteomics_Aliquot_ID Proteomics_Tumor_Normal        Country  \
# 0         CPT0001460012                   Tumor  United States
# 1         CPT0001300009                   Tumor  United States
# 2         CPT0001420009                   Tumor  United States
# 3         CPT0000820012                   Tumor            NaN
# 4         CPT0001140003                   Tumor  United States
#
#   Histologic_type Path_Stage_Primary_Tumor-pT Path_Stage_Reg_Lymph_Nodes-pN  \
# 0    Endometrioid              pT1a (FIGO IA)                           pN0
# 1    Endometrioid              pT1a (FIGO IA)                           pNX
# 2    Endometrioid              pT1a (FIGO IA)                           pN0
# 3  Carcinosarcoma                         NaN                           NaN
# 4    Endometrioid              pT1a (FIGO IA)                           pNX
#
#   Clin_Stage_Dist_Mets-cM  ...                        PMS2  \
# 0                     cM0  ...   Intact nuclear expression
# 1                     cM0  ...  Loss of nuclear expression
# 2                     cM0  ...   Intact nuclear expression
# 3                     NaN  ...                         NaN
# 4                     cM0  ...   Intact nuclear expression
#
#                     p53  MLH1_Promoter_Hypermethylation  \
# 0  Cannot be determined            Cannot be determined
# 1  Cannot be determined            Cannot be determined
# 2  Cannot be determined            Cannot be determined
# 3                   NaN                             NaN
# 4  Cannot be determined            Cannot be determined
#
#   Num_full_term_pregnancies ESTIMATE_StromalScore ESTIMATE_ESTIMATEScore  \
# 0                         1           2821.088429            7706.697310
# 1                         1           2714.248104            6346.448091
# 2                 4 or more           3856.501277           10459.413600
# 3                       NaN                   NaN                    NaN
# 4                 4 or more           3012.556593            7475.466867
#
#   CNV_class MSI_status POLE_subtype Genomics_subtype
# 0   CNV_LOW      MSI-H           No            MSI-H
# 1   CNV_LOW      MSI-H           No            MSI-H
# 2   CNV_LOW        MSS           No          CNV_low
# 3       NaN        MSS           No              NaN
# 4   CNV_LOW        MSS           No          CNV_low
#
# [5 rows x 34 columns]

# %% [markdown]
# #### Finding column matches between two tables

# %% [markdown]
# `bdi-kit` offers a suite of functions to help with data harmonization tasks.
#
# For instance, it can help automatically discover one-to-one mappings between the source and target dataset columns.
#
# To do so using `bdi-kit`, we can use the `match_schema()` function to match columns of the two schemas as follows. The `method` parameter allows modifying the schema matching algorithm used to perform the matching.
#
# ```python
# bdi.match_schema(df_source, df_target, method="jaccard_distance")
# bdi.match_schema(df_source, df_target, method="coma")
# bdi.match_schema(df_source, df_target, method="similarity_flooding")
# ```
#
# The method we use below is based on a pre-trained language model fine-tuned for the biomedical domain.
#
# For all methods available, see: [https://bdi-kit.readthedocs.io/en/latest/schema-matching.html](https://bdi-kit.readthedocs.io/en/latest/schema-matching.html)

# %%
schema_mapping = bdi.match_schema(df_source, df_target, method="max_val_sim")
schema_mapping.head(15)
# Out:
# /opt/miniconda3/envs/bdf/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
#                             source  \
# 0                             Race
# 1                       MSI_status
# 2                    Case_excluded
# 3         tumor_Stage-Pathological
# 4                        Ethnicity
# 5                   Tumor_Focality
# 6                           Gender
# 7        Num_full_term_pregnancies
# 8                     POLE_subtype
# 9   MLH1_Promoter_Hypermethylation
# 10     Path_Stage_Primary_Tumor-pT
# 11                Tumor_Site_Other
# 12                      Tumor_Site
# 13                   Tumor_Size_cm
# 14                 Histologic_type
#
#                                                target  similarity
# 0                                                Race    1.000000
# 1                                          MSI_status    1.000000
# 2                                       Case_excluded    1.000000
# 3                            Tumor_stage_pathological    1.000000
# 4                                           Ethnicity    1.000000
# 5                                      Tumor_focality    1.000000
# 6                                                 Sex    0.995859
# 7   Donor_information_number_of_full_term_pregnancies    0.984231
# 8                                                POLE    0.981701
# 9    Ancillary_studies_mlh1_promoter_hypermethylation    0.964056
# 10                Pathologic_staging_primary_tumor_pt    0.945246
# 11                                   Tumor_site_other    0.929722
# 12                                         Tumor_site    0.924333
# 13                                      Tumor_size_cm    0.888654
# 14                                    Histologic_Type    0.877000

# %% [markdown]
# #### Inspecting values of each column

# %%
bdi.preview_domain(df_source, 'Proteomics_Participant_ID').head(5)
# Out:
#   value_name
# 0  C3L-00006
# 1  C3L-00008
# 2  C3L-00032
# 3  C3L-00084
# 4  C3L-00090

# %%
bdi.preview_domain(df_target, 'Case_id').head(5)
# Out:
#   value_name
# 0  C3L-00086
# 1  C3L-00898
# 2  C3L-00943
# 3  C3L-01064
# 4  C3L-01277

# %% [markdown]
# #### Finding value matches between two columns

# %% [markdown]
# Once the matching columns are identified, we can standardize data to ensure that no duplicate values represent the same entity/meaning.
#
# To do that, `bdikit` provides the function `match_values()` to find values that should potentially be merged. The library supports multiple methods to perform this task, including syntactic and semantic matching algorithms. In this example, we use the `tfidf` method, which finds values based on the similarity of character n-grams. Please, refer to the [bdikit documentation](https://bdi-kit.readthedocs.io/) to learn more about the methods available.

# %%
# Matches values from each pair of source-target columns
value_matches = bdi.match_values(df_source, df_target, schema_mapping, method="tfidf")

# Print value matches
bdi.view_value_matches(value_matches, edit=False)
# Out:
# <br>**Source column:** Race<br>**Target column:** Race<br>
#                 source_value               target_value  similarity
# 0                      White                      White         1.0
# 1                      White                      White         1.0
# 2                      Asian                      Asian         1.0
# 3               Not Reported               Not Reported         1.0
# 4  Black or African American  Black or African American         1.0
# 5                        NaN                        NaN         NaN
# <br>**Source column:** MSI_status<br>**Target column:** MSI_status<br>
#   source_value target_value  similarity
# 0        MSI-H        MSI-H         1.0
# 1          MSS          MSS         1.0
# 2          NaN          NaN         NaN
# <br>**Source column:** Case_excluded<br>**Target column:** Case_excluded<br>
#   source_value target_value  similarity
# 0           No           No         1.0
# 1          Yes          Yes         1.0
# <br>**Source column:** tumor_Stage-Pathological<br>**Target column:** Tumor_stage_pathological<br>
#   source_value target_value  similarity
# 0      Stage I      Stage I         1.0
# 1     Stage IV     Stage IV         1.0
# 2    Stage III    Stage III         1.0
# 3     Stage II     Stage II         1.0
# 4          NaN          NaN         NaN
# <br>**Source column:** Ethnicity<br>**Target column:** Ethnicity<br>
#              source_value            target_value  similarity
# 0  Not-Hispanic or Latino  Not-Hispanic or Latino         1.0
# 1      Hispanic or Latino      Hispanic or Latino         1.0
# 2            Not reported            Not reported         1.0
# 3                     NaN                     NaN         NaN
# <br>**Source column:** Tumor_Focality<br>**Target column:** Tumor_focality<br>
#   source_value target_value  similarity
# 0     Unifocal     Unifocal         1.0
# 1   Multifocal   Multifocal         1.0
# 2          NaN          NaN         NaN
# <br>**Source column:** Gender<br>**Target column:** Sex<br>
#   source_value target_value  similarity
# 0       Female       Female         1.0
# 1          NaN          NaN         NaN
# <br>**Source column:** Num_full_term_pregnancies<br>**Target column:** Donor_information_number_of_full_term_pregnancies<br>
#   source_value target_value  similarity
# 0            1            1         1.0
# 1    4 or more    4 or more         1.0
# 2            2            2         1.0
# 3            3            3         1.0
# 4      Unknown      Unknown         1.0
# 5          NaN          NaN         NaN
# <br>**Source column:** POLE_subtype<br>**Target column:** POLE<br>
#   source_value target_value  similarity
# 0           No           No         1.0
# 1          Yes          Yes         1.0
# 2          NaN          NaN         NaN
# <br>**Source column:** MLH1_Promoter_Hypermethylation<br>**Target column:** Ancillary_studies_mlh1_promoter_hypermethylation<br>
#            source_value          target_value  similarity
# 0  Cannot be determined  Cannot be determined         1.0
# 1                Absent                Absent         1.0
# 2               Present               Present         1.0
# 3                   NaN                   NaN         NaN
# <br>**Source column:** Path_Stage_Primary_Tumor-pT<br>**Target column:** Pathologic_staging_primary_tumor_pt<br>
#        source_value      target_value  similarity
# 0    pT1a (FIGO IA)    pT1a (FIGO IA)         1.0
# 1  pT3a (FIGO IIIA)  pT3a (FIGO IIIA)         1.0
# 2      pT1 (FIGO I)      pT1 (FIGO I)         1.0
# 3    pT1b (FIGO IB)    pT1b (FIGO IB)         1.0
# 4     pT2 (FIGO II)     pT2 (FIGO II)         1.0
# 5  pT3b (FIGO IIIB)  pT3b (FIGO IIIB)         1.0
# 6               NaN               NaN         NaN
# <br>**Source column:** Tumor_Site_Other<br>**Target column:** Tumor_site_other<br>
#                                          source_value  \
# 0                  Anterior and Posterior endometrium
# 1                 Anterior  and Posterior endometrium
# 2                         Both anterior and posterior
# 3                  Anterior and Posterior Endometrium
# 4             Both anterior and posterior endometrium
# 5                  Anterior and posterior endometrium
# 6                              Anterior and Posterior
# 7                  Posterior and Anterior Endometrium
# 8                              anterior and posterior
# 9                         both anterior and posterior
# 10                              Entire uterine cavity
# 11                                     Uterine cavity
# 12                              Entire Uterine Cavity
# 13                             Entire uterine cavity.
# 14                                        Endometrium
# 15                              entire uterine cavity
# 16          anterior and posterior endometrial cavity
# 17      Involves fundus, anterior and posterior walls
# 18                     Anterior, posterior and fundus
# 19          Tumor occupies 75% of endometrial surface
# 20  Both anterior and posterior endometrium are re...
# 21               along anterior and posterior surface
# 22  If Other, specify: Tumor occupies 100% of endo...
# 23  Tumor involves 75% of endometrial cavity per d...
# 24  Bulky tumor involving both anterior and poster...
# 25        100 PERCENT OF ENDOMETRIAL SURFACE INVOLVED
# 26                                         left cornu
# 27                                                NaN
#
#                                     target_value  similarity
# 0             Anterior and posterior endometrium       1.000
# 1             Anterior and posterior endometrium       1.000
# 2                    Both anterior and posterior       1.000
# 3             Anterior and posterior endometrium       1.000
# 4        Both anterior and posterior endometrium       1.000
# 5             Anterior and posterior endometrium       1.000
# 6                         anterior and posterior       1.000
# 7             Anterior and posterior endometrium       1.000
# 8                         anterior and posterior       1.000
# 9                    Both anterior and posterior       1.000
# 10                         Entire uterine cavity       1.000
# 11                                Uterine cavity       1.000
# 12                         Entire uterine cavity       1.000
# 13                         Entire uterine cavity       1.000
# 14                                   Endometrium       1.000
# 15                         Entire uterine cavity       1.000
# 16            Anterior and posterior endometrium       0.831
# 17               Involves anterior and posterior       0.784
# 18                        anterior and posterior       0.782
# 19      Tumor occupies 80% of endometrial cavity       0.730
# 20       Both anterior and posterior endometrium       0.704
# 21                        anterior and posterior       0.641
# 22      Tumor occupies 80% of endometrial cavity       0.630
# 23  Tumor involves the entire endometrial cavity       0.617
# 24               Involves anterior and posterior       0.603
# 25  Tumor involves the entire endometrial cavity       0.507
# 26                   left side of uterine cavity       0.376
# 27                                           NaN         NaN
# <br>**Source column:** Tumor_Site<br>**Target column:** Tumor_site<br>
#             source_value           target_value  similarity
# 0   Anterior endometrium   Anterior endometrium       1.000
# 1  Posterior endometrium  Posterior endometrium       1.000
# 2         Other, specify                  Other       0.546
# 3                    NaN                    NaN         NaN
# <br>**Source column:** Progesterone_Receptor<br>**Target column:** Ancillary_studies_progesterone_receptor<br>
#            source_value          target_value  similarity
# 0  Cannot be determined  Cannot be determined       1.000
# 1              Negative              Negative       1.000
# 2              Positive        Positive : 5 %       0.938
# 3                   NaN                   NaN         NaN
# 4               Unknown                   NaN         NaN
# <br>**Source column:** Estrogen_Receptor<br>**Target column:** Ancillary_studies_estrogen_receptor<br>
#            source_value          target_value  similarity
# 0  Cannot be determined  Cannot be determined       1.000
# 1              Negative              Negative       1.000
# 2              Positive        Positive : 5 %       0.937
# 3                   NaN                   NaN         NaN
# 4               Unknown                   NaN         NaN
# <br>**Source column:** p53<br>**Target column:** Ancillary_studies_p53<br>
#            source_value          target_value  similarity
# 0  Cannot be determined  Cannot be determined         1.0
# 1                Normal                Normal         1.0
# 2        Overexpression        Overexpression         1.0
# 3    Loss of expression    Loss of expression         1.0
# 4                   NaN                   NaN         NaN
# 5               Unknown                   NaN         NaN
# <br>**Source column:** Country<br>**Target column:** Participant_country<br>
#     source_value   target_value  similarity
# 0  United States  United States         1.0
# 1        Ukraine        Ukraine         1.0
# 2         Poland         Poland         1.0
# 3  Other_specify            NaN         NaN
# 4            NaN            NaN         NaN
# <br>**Source column:** Clin_Stage_Dist_Mets-cM<br>**Target column:** Clinical_staging_distant_metastasis_cm<br>
#          source_value        target_value  similarity
# 0                 cM0                 cM0         1.0
# 1  Staging Incomplete  Staging Incomplete         1.0
# 2                 cM1                 cM1         1.0
# 3                 NaN                 NaN         NaN
# <br>**Source column:** Genomics_subtype<br>**Target column:** Genomic_subtype<br>
#   source_value target_value  similarity
# 0        MSI-H        MSI-H       1.000
# 1         POLE         POLE       1.000
# 2      CNV_low        CNV_L       0.658
# 3     CNV_high        CNV_H       0.625
# 4          NaN          NaN         NaN
# <br>**Source column:** Diabetes<br>**Target column:** Diabetes<br>
#   source_value target_value  similarity
# 0          Yes          Yes         1.0
# 1           No          NaN         NaN
# 2      Unknown          NaN         NaN
# 3          NaN          NaN         NaN
# <br>**Source column:** MLH1<br>**Target column:** Ancillary_studies_msh2<br>
#                  source_value                target_value  similarity
# 0   Intact nuclear expression   Intact nuclear expression         1.0
# 1  Loss of nuclear expression  Loss of nuclear expression         1.0
# 2        Cannot be determined        Cannot be determined         1.0
# 3                         NaN                         NaN         NaN
# 4                     Unknown                         NaN         NaN
# <br>**Source column:** Path_Stage_Reg_Lymph_Nodes-pN<br>**Target column:** Pathologic_staging_regional_lymph_nodes_pn<br>
#        source_value      target_value  similarity
# 0               pN0               pN0         1.0
# 1               pNX               pNX         1.0
# 2  pN2 (FIGO IIIC2)  pN2 (FIGO IIIC2)         1.0
# 3  pN1 (FIGO IIIC1)  pN1 (FIGO IIIC1)         1.0
# 4               NaN               NaN         NaN
# <br>**Source column:** Proteomics_TMT_channel<br>**Target column:** ReporterName<br>
#   source_value target_value  similarity
# 0         128N         128N       1.000
# 1         130N         130N       1.000
# 2         129N         129N       1.000
# 3         129C         129C       1.000
# 4         130C         130C       1.000
# 5         127C         127C       1.000
# 6         127N         127N       1.000
# 7         128C         128C       1.000
# 8          131         131N       0.709
# <br>**Source column:** Proteomics_Tumor_Normal<br>**Target column:** Group<br>
#         source_value     target_value  similarity
# 0              Tumor            Tumor         1.0
# 1    Adjacent_normal  Adjacent_normal         1.0
# 2    Enriched_normal  Enriched_Normal         1.0
# 3  Myometrium_normal              NaN         NaN
# <br>**Source column:** PMS2<br>**Target column:** Ancillary_studies_pms2<br>
#                  source_value                target_value  similarity
# 0   Intact nuclear expression   Intact nuclear expression         1.0
# 1  Loss of nuclear expression  Loss of nuclear expression         1.0
# 2        Cannot be determined        Cannot be determined         1.0
# 3                         NaN                         NaN         NaN
# 4                     Unknown                         NaN         NaN
# <br>**Source column:** Proteomics_Aliquot_ID<br>**Target column:** Aliquot_ID<br>
#       source_value   target_value  similarity
# 0    CPT0026530003  CPT0265300003       0.959
# 1    CPT0016940003  CPT0116940003       0.860
# 2    CPT0018960003  CPT0089600003       0.771
# 3    CPT0097730003  CPT0097300003       0.757
# 4    CPT0027520003  CPT0275270003       0.743
# ..             ...            ...         ...
# 148  CPT0077660001  CPT0126000003       0.343
# 149  CPT0063900001  CPT0100010003       0.343
# 150  CPT0064240001  CPT0129640003       0.319
# 151  CPT0076680003  CPT0230070003       0.318
# 152  CPT0066620003            NaN         NaN
#
# [153 rows x 3 columns]
# <br>**Source column:** Histologic_type<br>**Target column:** Histologic_Type<br>
#      source_value            target_value  similarity
# 0    Endometrioid  Endometrioid carcinoma       0.854
# 1      Clear cell    Clear cell carcinoma       0.836
# 2          Serous        Serous carcinoma       0.715
# 3  Carcinosarcoma        Serous carcinoma       0.611
# 4             NaN                     NaN         NaN
# <br>**Source column:** Proteomics_Participant_ID<br>**Target column:** Idx<br>
#     source_value target_value  similarity
# 0      C3N-01003    C3N-01008       0.809
# 1      C3N-01001    C3N-01008       0.808
# 2      C3L-00008    C3L-00086       0.781
# 3      C3L-00358    C3L-03589       0.718
# 4      C3N-01520    C3N-01525       0.713
# ..           ...          ...         ...
# 118    C3L-00769          NaN         NaN
# 119          NX5          NaN         NaN
# 120          NX3          NaN         NaN
# 121         NX11          NaN         NaN
# 122         NX18          NaN         NaN
#
# [123 rows x 3 columns]
# <br>**Source column:** CNV_class<br>**Target column:** CNV_status<br>
#   source_value target_value  similarity
# 0      CNV_LOW        CNV_L       0.607
# 1     CNV_HIGH        CNV_H       0.603
# 2          NaN          NaN         NaN

# %% [markdown]
# #### Generating a harmonized table

# %% [markdown]
# After verifying and fixing value mappings, we can proceed to generate a harmonized table.
#
# In bdikit, we can do this using the `bdi.materialize_mapping()` function.

# %%
df_mapped = bdi.materialize_mapping(df_source, value_matches)
df_mapped.head(5)
# Out:
#     Race MSI_status Case_excluded Tumor_stage_pathological  \
# 0  White      MSI-H            No                  Stage I
# 1  White      MSI-H            No                 Stage IV
# 2  White        MSS            No                  Stage I
# 3    NaN        MSS           Yes                      NaN
# 4  White        MSS            No                  Stage I
#
#                 Ethnicity Tumor_focality     Sex  \
# 0  Not-Hispanic or Latino       Unifocal  Female
# 1  Not-Hispanic or Latino       Unifocal  Female
# 2  Not-Hispanic or Latino       Unifocal  Female
# 3                     NaN            NaN     NaN
# 4  Not-Hispanic or Latino       Unifocal  Female
#
#   Donor_information_number_of_full_term_pregnancies POLE  \
# 0                                                 1   No
# 1                                                 1   No
# 2                                         4 or more   No
# 3                                               NaN   No
# 4                                         4 or more   No
#
#   Ancillary_studies_mlh1_promoter_hypermethylation  ... Diabetes  \
# 0                             Cannot be determined  ...      NaN
# 1                             Cannot be determined  ...      NaN
# 2                             Cannot be determined  ...      Yes
# 3                                              NaN  ...      NaN
# 4                             Cannot be determined  ...      NaN
#
#       Ancillary_studies_msh2 Pathologic_staging_regional_lymph_nodes_pn  \
# 0  Intact nuclear expression                                        pN0
# 1  Intact nuclear expression                                        pNX
# 2  Intact nuclear expression                                        pN0
# 3                        NaN                                        NaN
# 4  Intact nuclear expression                                        pNX
#
#   ReporterName  Group      Ancillary_studies_pms2     Aliquot_ID  \
# 0         128N  Tumor   Intact nuclear expression  CPT0126000003
# 1         130N  Tumor  Loss of nuclear expression  CPT0095130004
# 2         131N  Tumor   Intact nuclear expression  CPT0313420004
# 3         129N  Tumor                         NaN  CPT0182020004
# 4         129C  Tumor   Intact nuclear expression  CPT0114340003
#
#           Histologic_Type        Idx CNV_status
# 0  Endometrioid carcinoma  C3L-00086      CNV_L
# 1  Endometrioid carcinoma  C3L-00086      CNV_L
# 2  Endometrioid carcinoma  C3L-00086      CNV_L
# 3        Serous carcinoma  C3L-00086        NaN
# 4  Endometrioid carcinoma  C3L-00086      CNV_L
#
# [5 rows x 29 columns]

# %% [markdown]
# For comparisson sake, here is how these columns looked like in the original table:

# %%
source_column_names = value_matches['source_attribute'].unique().tolist()
target_column_names = value_matches['target_attribute'].unique().tolist()
df_source[source_column_names].head(5)
# Out:
#     Race MSI_status Case_excluded tumor_Stage-Pathological  \
# 0  White      MSI-H            No                  Stage I
# 1  White      MSI-H            No                 Stage IV
# 2  White        MSS            No                  Stage I
# 3    NaN        MSS           Yes                      NaN
# 4  White        MSS            No                  Stage I
#
#                 Ethnicity Tumor_Focality  Gender Num_full_term_pregnancies  \
# 0  Not-Hispanic or Latino       Unifocal  Female                         1
# 1  Not-Hispanic or Latino       Unifocal  Female                         1
# 2  Not-Hispanic or Latino       Unifocal  Female                 4 or more
# 3                     NaN            NaN     NaN                       NaN
# 4  Not-Hispanic or Latino       Unifocal  Female                 4 or more
#
#   POLE_subtype MLH1_Promoter_Hypermethylation  ... Diabetes  \
# 0           No           Cannot be determined  ...       No
# 1           No           Cannot be determined  ...       No
# 2           No           Cannot be determined  ...      Yes
# 3           No                            NaN  ...      NaN
# 4           No           Cannot be determined  ...       No
#
#                         MLH1 Path_Stage_Reg_Lymph_Nodes-pN  \
# 0  Intact nuclear expression                           pN0
# 1  Intact nuclear expression                           pNX
# 2  Intact nuclear expression                           pN0
# 3                        NaN                           NaN
# 4  Intact nuclear expression                           pNX
#
#   Proteomics_TMT_channel Proteomics_Tumor_Normal                        PMS2  \
# 0                   128N                   Tumor   Intact nuclear expression
# 1                   130N                   Tumor  Loss of nuclear expression
# 2                    131                   Tumor   Intact nuclear expression
# 3                   129N                   Tumor                         NaN
# 4                   129C                   Tumor   Intact nuclear expression
#
#   Proteomics_Aliquot_ID Histologic_type Proteomics_Participant_ID CNV_class
# 0         CPT0001460012    Endometrioid                 C3L-00006   CNV_LOW
# 1         CPT0001300009    Endometrioid                 C3L-00008   CNV_LOW
# 2         CPT0001420009    Endometrioid                 C3L-00032   CNV_LOW
# 3         CPT0000820012  Carcinosarcoma                 C3L-00084       NaN
# 4         CPT0001140003    Endometrioid                 C3L-00090   CNV_LOW
#
# [5 rows x 29 columns]

# %% [markdown]
# The final step is to merge the two tables in a single harmonized dataset.

# %%
merged_table = pd.concat([df_mapped[target_column_names], df_target[target_column_names]])
merged_table.head(10)
# Out:
#     Race MSI_status Case_excluded Tumor_stage_pathological  \
# 0  White      MSI-H            No                  Stage I
# 1  White      MSI-H            No                 Stage IV
# 2  White        MSS            No                  Stage I
# 3    NaN        MSS           Yes                      NaN
# 4  White        MSS            No                  Stage I
# 5  White        MSS            No                  Stage I
# 6  White        MSS            No                  Stage I
# 7  White        MSS            No                  Stage I
# 8  White        MSS            No                Stage III
# 9  White      MSI-H            No                  Stage I
#
#                 Ethnicity Tumor_focality     Sex  \
# 0  Not-Hispanic or Latino       Unifocal  Female
# 1  Not-Hispanic or Latino       Unifocal  Female
# 2  Not-Hispanic or Latino       Unifocal  Female
# 3                     NaN            NaN     NaN
# 4  Not-Hispanic or Latino       Unifocal  Female
# 5  Not-Hispanic or Latino       Unifocal  Female
# 6  Not-Hispanic or Latino       Unifocal  Female
# 7  Not-Hispanic or Latino       Unifocal  Female
# 8  Not-Hispanic or Latino       Unifocal  Female
# 9  Not-Hispanic or Latino       Unifocal  Female
#
#   Donor_information_number_of_full_term_pregnancies POLE  \
# 0                                                 1   No
# 1                                                 1   No
# 2                                         4 or more   No
# 3                                               NaN   No
# 4                                         4 or more   No
# 5                                                 2   No
# 6                                                 3   No
# 7                                                 2   No
# 8                                         4 or more   No
# 9                                                 2   No
#
#   Ancillary_studies_mlh1_promoter_hypermethylation  ... Diabetes  \
# 0                             Cannot be determined  ...      NaN
# 1                             Cannot be determined  ...      NaN
# 2                             Cannot be determined  ...      Yes
# 3                                              NaN  ...      NaN
# 4                             Cannot be determined  ...      NaN
# 5                             Cannot be determined  ...      NaN
# 6                             Cannot be determined  ...      NaN
# 7                             Cannot be determined  ...      NaN
# 8                             Cannot be determined  ...      NaN
# 9                             Cannot be determined  ...      Yes
#
#        Ancillary_studies_msh2 Pathologic_staging_regional_lymph_nodes_pn  \
# 0   Intact nuclear expression                                        pN0
# 1   Intact nuclear expression                                        pNX
# 2   Intact nuclear expression                                        pN0
# 3                         NaN                                        NaN
# 4   Intact nuclear expression                                        pNX
# 5   Intact nuclear expression                                        pNX
# 6   Intact nuclear expression                                        pNX
# 7   Intact nuclear expression                                        pNX
# 8   Intact nuclear expression                                        pNX
# 9  Loss of nuclear expression                                        pN0
#
#   ReporterName  Group      Ancillary_studies_pms2     Aliquot_ID  \
# 0         128N  Tumor   Intact nuclear expression  CPT0126000003
# 1         130N  Tumor  Loss of nuclear expression  CPT0095130004
# 2         131N  Tumor   Intact nuclear expression  CPT0313420004
# 3         129N  Tumor                         NaN  CPT0182020004
# 4         129C  Tumor   Intact nuclear expression  CPT0114340003
# 5         129N  Tumor   Intact nuclear expression  CPT0127980003
# 6         129C  Tumor   Intact nuclear expression  CPT0117300003
# 7         130N  Tumor   Intact nuclear expression  CPT0100100003
# 8         130N  Tumor   Intact nuclear expression  CPT0113850003
# 9         130C  Tumor  Loss of nuclear expression  CPT0091910003
#
#           Histologic_Type        Idx CNV_status
# 0  Endometrioid carcinoma  C3L-00086      CNV_L
# 1  Endometrioid carcinoma  C3L-00086      CNV_L
# 2  Endometrioid carcinoma  C3L-00086      CNV_L
# 3        Serous carcinoma  C3L-00086        NaN
# 4  Endometrioid carcinoma  C3L-00086      CNV_L
# 5        Serous carcinoma  C3L-00086      CNV_H
# 6  Endometrioid carcinoma  C3L-01355      CNV_L
# 7  Endometrioid carcinoma  C3L-01355      CNV_L
# 8        Serous carcinoma  C3L-01355      CNV_H
# 9  Endometrioid carcinoma  C3L-03143      CNV_L
#
# [10 rows x 29 columns]
