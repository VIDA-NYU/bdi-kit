# %%
import seaborn as sns
import pandas as pd
from valentine.algorithms import Coma
from valentine.algorithms import JaccardDistanceMatcher
from valentine.algorithms import SimilarityFlooding
from valentine.algorithms import DistributionBased
from valentine.algorithms import Cupid
from valentine.metrics import F1Score, PrecisionTopNPercent
from valentine import valentine_match
import pprint
import glob
from column_representation import ColumnRepresentation, gdc_target_columns, gdc_df

from polyfuzz import PolyFuzz
from polyfuzz.models import EditDistance
from jellyfish import jaro_winkler_similarity
from polyfuzz.models import Embeddings
from flair.embeddings import TransformerWordEmbeddings, WordEmbeddings

from gdc.gdc_api import GDCSchema
import utils.file_utils as ut
import sys
import os
sys.path.append(os.path.join(os.path.abspath(''), '..'))


sns.set_theme(style="white")


pp = pprint.PrettyPrinter(indent=4, sort_dicts=True)

ground_truth_path = os.path.join(
    '..', 'data', 'table-matching-ground-truth', 'ground-truth')
csv_data_path = os.path.join('..', 'data', 'extracted-tables')

cat_null_values = set(['n/a', 'na', 'nan', 'null', 'lost to follow-up', 'not available', 'unable to obtain',
                       'unknown', 'not reported', 'not allowed to collect',
                       'unspecified', 'not specified', 'other, specify','none'])

DOMAIN_SIMILARITY_THRESHOLD = 0.5

# %%
df_target = pd.read_csv('../data/target.csv')
df_target.drop('study', axis=1, inplace=True)
print(df_target.shape)
df_target.head(5)
# Out:
# (1068, 16)
#   case_submitter_id  age_at_diagnosis                       race  \
# 0           01BR001           20089.0  black or african american
# 1           01BR008           17532.0  black or african american
# 2           01BR009           23376.0  black or african american
# 3           01BR010           23741.0  black or african american
# 4           01BR015           12784.0                      white
#
#                 ethnicity  gender  vital_status ajcc_pathologic_t  \
# 0  not hispanic or latino  female         Alive                T2
# 1  not hispanic or latino  female  Not Reported      Not Reported
# 2  not hispanic or latino  female  Not Reported      Not Reported
# 3  not hispanic or latino  female  Not Reported      Not Reported
# 4  not hispanic or latino  female         Alive                T2
#
#   ajcc_pathologic_n ajcc_pathologic_stage tumor_grade tumor_focality  \
# 0               N1c              Stage II          GX   Not Reported
# 1      Not Reported          Not Reported          GX   Not Reported
# 2      Not Reported          Not Reported          GX   Not Reported
# 3      Not Reported          Not Reported          GX   Not Reported
# 4                N1              Stage II          GX   Not Reported
#
#   tumor_largest_dimension_diameter                      primary_diagnosis  \
# 0                     Not Reported  Invasive carcinoma of no special type
# 1                     Not Reported                           Not Reported
# 2                     Not Reported                           Not Reported
# 3                     Not Reported                           Not Reported
# 4                     Not Reported  Invasive carcinoma of no special type
#
#      morphology tissue_or_organ_of_origin tumor_code
# 0        8500/3               Breast, NOS       BRCA
# 1  Not Reported               Breast, NOS       BRCA
# 2  Not Reported               Breast, NOS       BRCA
# 3  Not Reported               Breast, NOS       BRCA
# 4        8500/3               Breast, NOS       BRCA

# %%
interested_cols = set(df_target.columns)
interested_cols.remove('case_submitter_id')
interested_cols
# Out:
# {'age_at_diagnosis',
#  'ajcc_pathologic_n',
#  'ajcc_pathologic_stage',
#  'ajcc_pathologic_t',
#  'ethnicity',
#  'gender',
#  'morphology',
#  'primary_diagnosis',
#  'race',
#  'tissue_or_organ_of_origin',
#  'tumor_code',
#  'tumor_focality',
#  'tumor_grade',
#  'tumor_largest_dimension_diameter',
#  'vital_status'}

# %%
gdc_df
gdc_df.ajcc_pathologic_t.unique()
# Out:
# array(['t2d', 't1b', 't2c', 't1b1', 'tx', 't1', 't4a', 't4e', 't0', 't3a',
#        't1mi', 't2a', 't4c', 't1c2', 'tis', 't2a1', 't3b', 't2',
#        'tis (dcis)', 't1c', 't1a2', 't3d', 't4b', 't4', 't1a1',
#        'tis (lcis)', 't2a2', 't3', "tis (paget's)", 't1b2', 't3c', 'ta',
#        't1a', 't4d', 't2b', <NA>], dtype=object)

# %%
def calculate_metrics(groundtruth, matching_pairs):
    
    true_positives = len(set(groundtruth) & set(matching_pairs))
    false_positives = len(set(matching_pairs) - set(groundtruth))
    false_negatives = len(set(groundtruth) - set(matching_pairs))
    
    precision = true_positives / (true_positives + false_positives)
    recall = true_positives / (true_positives + false_negatives) 
    f1_score = 2 * (precision * recall) / (precision + recall)
    
    return precision, recall, f1_score

# %%
def check_domains_tf(colvalues1, colvalues2):
    model = PolyFuzz("TF-IDF").match(colvalues1, colvalues2)
    value_matches = model.get_matches()
    # model.visualize_precision_recall()
    # print(value_matches)
    value_matches = value_matches.dropna()
    # print(value_matches)
    n = len(colvalues1)
    # get the first elements according to the domain size of the candidate
    value_matches = value_matches.head(n)

    return value_matches['Similarity'].median()


def check_domains_edit(colvalues1, colvalues2):
    jellyfish_matcher = EditDistance(n_jobs=1, scorer=jaro_winkler_similarity)
    model = PolyFuzz(jellyfish_matcher).match(colvalues1, colvalues2)
    value_matches = model.get_matches()
    # print(value_matches)
    value_matches = value_matches.dropna()

    n = len(colvalues1)
    # get the first elements according to the domain size of the candidate
    value_matches = value_matches.head(n)

    return value_matches['Similarity'].median()


def check_domains_emb(colvalues1, colvalues2):

    bert = TransformerWordEmbeddings('bert-base-multilingual-cased')
    bert_matcher = Embeddings(bert, min_similarity=0)

    # fasttext = WordEmbeddings('en-crawl')
    # fasttext_matcher = Embeddings(fasttext, min_similarity=0)

    # matchers = [bert_matcher, fasttext_matcher]

    model = PolyFuzz(bert_matcher).match(colvalues1, colvalues2)

    value_matches = model.get_matches()

    print(value_matches)

    # value_matches = value_matches.dropna()

    # n = len(colvalues1)
    # # get the first elements according to the domain size of the candidate
    # value_matches = value_matches.head(n)

    # return value_matches['Similarity'].median()

# %%
value_ocurrence_map ={}
files = []
for file in os.listdir(ground_truth_path):
    study = file.split('.csv')[0]

    groundtruth_path = os.path.join(ground_truth_path, file)
    groundtruth = ut.load_table_matching_groundtruth(groundtruth_path)
    groundtruth = [
        entry for entry in groundtruth if entry[1] in set(gdc_df.columns)]
    groundtruth = [(entry[0].lower(), entry[1].lower()) for entry in groundtruth]
    
    for entry in groundtruth:
        value_ocurrence_map[entry[1]] = value_ocurrence_map.get(entry[1], 0) + 1
        if entry[1] == 'primary_diagnosis':
            files.append(study)

for k,v in value_ocurrence_map.items():
    if v > 1:
        print(k,v)

print(files)
# Out:
# ajcc_pathologic_stage 7
# gender 9
# ethnicity 6
# race 4
# tumor_focality 4
# primary_diagnosis 4
# tumor_grade 3
# ajcc_pathologic_t 5
# ajcc_pathologic_n 5
# vital_status 3
# ['Clark', 'Gillette', 'Huang', 'Dou']

# %%
import random

dataframe_dict = {}

for study in ['Clark', 'Gillette', 'Huang', 'Dou']:
    file = study + '.csv'

    groundtruth_path = os.path.join(ground_truth_path, file)
    groundtruth = ut.load_table_matching_groundtruth(groundtruth_path)
    groundtruth = [
        entry for entry in groundtruth if entry[1] in set(gdc_df.columns)]
    groundtruth = [(entry[0].lower(), entry[1].lower())
                   for entry in groundtruth]

    interested_entry = None
    for entry in groundtruth:
        if entry[1] == 'primary_diagnosis':
            interested_entry = entry

    # print(interested_entry)

    if interested_entry == None:
        continue

    files = glob.glob(os.path.join(csv_data_path, f"{study}*.csv"))

    

    for i, file in enumerate(files):
        # print(f"\nProcessing {file}")
        candidate_df = pd.read_csv(file)
        candidate_df.columns = candidate_df.columns.str.lower()

        if interested_entry[0] in candidate_df.columns:

            print(study, interested_entry[0], interested_entry[1])

            values = candidate_df[interested_entry[0]].unique()
            gdc_values = gdc_df[interested_entry[1]].unique()   

            # print(len(gdc_values))

            subset_size = 8  # Choose the size of the subset
            random_subset = set(random.sample(sorted(gdc_values), subset_size))

            dataframe_dict['GDC Format'] = list(random_subset)

            # print(values, random_subset)

            to_complete = subset_size - len(values)

            values = list(values)
            for i in range(to_complete):
                values.append('N/A')

            dataframe_dict[study] = values



            # common_values = set(values) & set(gdc_values)
            # proportion = len(common_values) / len(values)
            # print(f"{study} {file} {proportion}")

            # print(len(values), len(gdc_values), len(common_values))
# Out:
# Clark histologic_type primary_diagnosis
# Gillette dominant.histological.subtype primary_diagnosis
# Huang histologic_type primary_diagnosis
# Dou histologic_type primary_diagnosis

# %%
import pandas as pd


# Create DataFrame
df = pd.DataFrame(dataframe_dict)

# Print DataFrame
# print(df.head())

print(df.to_string(max_rows=None))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 5
#       1 import pandas as pd
#       4 # Create DataFrame
# ----> 5 df = pd.DataFrame(dataframe_dict)
#       7 # Print DataFrame
#       8 # print(df.head())
#      10 print(df.to_string(max_rows=None))
#
# File ~/miniconda3/envs/arpah/lib/python3.12/site-packages/pandas/core/frame.py:733, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     727     mgr = self._init_mgr(
#     728         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     729     )
#     731 elif isinstance(data, dict):
#     732     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 733     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     734 elif isinstance(data, ma.MaskedArray):
#     735     from numpy.ma import mrecords
#
# File ~/miniconda3/envs/arpah/lib/python3.12/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/miniconda3/envs/arpah/lib/python3.12/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~/miniconda3/envs/arpah/lib/python3.12/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
scores = {}
for file in os.listdir(ground_truth_path):

    # if 'Dou' not in file:
    #     continue

    study = file.split('.csv')[0]

    groundtruth_path = os.path.join(ground_truth_path, file)
    groundtruth = ut.load_table_matching_groundtruth(groundtruth_path)
    groundtruth = [
        entry for entry in groundtruth if entry[1] in set(gdc_df.columns)]
    groundtruth = [(entry[0].lower(), entry[1].lower()) for entry in groundtruth]
    print(len(groundtruth))
    print(groundtruth)

    files = glob.glob(os.path.join(csv_data_path, f"{study}*.csv"))

    matching_pairs = []

    for i, file in enumerate(files):
        
        

        print(f"\nProcessing {file}")
        candidate_df = pd.read_csv(file)
        candidate_df.columns = candidate_df.columns.str.lower()
        candidate_df = candidate_df.select_dtypes(exclude='number')

        # Exact match based on column names
        common_cols = list(
            set(candidate_df.columns).intersection(set(gdc_df.columns)))
        
        print('\nExact column name matches between candidate table and gdc', common_cols)
        for col in common_cols:
            print('Checking similarity values for column:', col)
            candidate_col_values =  candidate_df[col].dropna().astype(str).unique()
            candidate_col_values = [c.lower() for c in candidate_col_values if c.lower() not in cat_null_values]# remove null values and make it lower case
            target_col_values = gdc_df[col].dropna().astype(str).unique()
            target_col_values = [c.lower() for c in target_col_values] # mae it lower case
            domain_similarity_avg = check_domains_tf(candidate_col_values, target_col_values)
            if domain_similarity_avg > DOMAIN_SIMILARITY_THRESHOLD:
                matching_pairs.append((col, col))

            print(f"Domain similarity for {col} is {domain_similarity_avg}")
            print('-'*60)
        print('\n')

        ## Checking similarity based on column names

        # TF-IDF      
        model = PolyFuzz("TF-IDF").match(list(candidate_df.columns), list(gdc_df.columns))
        name_matches = model.get_matches()
        # Edit Distance model
        # jellyfish_matcher = EditDistance(n_jobs=1, scorer=jaro_winkler_similarity)
        # model = PolyFuzz(jellyfish_matcher).match(list(candidate_df.columns), list(gdc_df.columns))
        # name_matches = model.get_matches()
                                          
        name_matches = name_matches[(name_matches['Similarity'] >= 0.4) & (name_matches['Similarity'] < 1.0)] ## get similar matches
        print('Similar column name matches between candidate table and gdc')
        print(name_matches) 
        print('\n')

        for match in name_matches.itertuples():
            print('Checking similarity values for column:', match[1], match[2])
            candidate_col_values =  candidate_df[match[1]].dropna().astype(str).unique()
            candidate_col_values = [c.lower() for c in candidate_col_values if c.lower() not in cat_null_values]
            
            
            target_col_values = gdc_df[match[2]].dropna().astype(str).unique()
            target_col_values = [c.lower() for c in target_col_values ]
            
            domain_similarity_avg = check_domains_tf(candidate_col_values, target_col_values)
            if domain_similarity_avg > DOMAIN_SIMILARITY_THRESHOLD:
                matching_pairs.append((match[1], match[2]))
            print(f"Domain similarity for {match[1]} and {match[2]} is {domain_similarity_avg}")
            print('-'*60) 


        # checking the remaining of the candidates
        print('\nChecking similarity values for remaining columns')
            
        candidate_cols = set(candidate_df.columns)
        remaining_cols = list(candidate_cols - set([pair[0] for pair in matching_pairs]))

        target_cols = set(gdc_df.columns)
        remaining_target_cols = list(target_cols - set([pair[1] for pair in matching_pairs]))
        
        pairwise_elements = list(zip(remaining_cols, remaining_target_cols))
        print(pairwise_elements)

        for pair in pairwise_elements:
            # print('\nChecking similarity values for column:', pair[0], pair[1])
            candidate_col_values =  candidate_df[pair[0]].dropna().astype(str).unique()
            candidate_col_values = [c.lower() for c in candidate_col_values if c.lower() not in cat_null_values]
            
            target_col_values = gdc_df[pair[1]].dropna().astype(str).unique()
            target_col_values = [c.lower() for c in target_col_values ]
            domain_similarity_avg = check_domains_tf(candidate_col_values, target_col_values)
            # domain_similarity_avg = check_domains_emb(candidate_col_values, target_col_values)
            if domain_similarity_avg > DOMAIN_SIMILARITY_THRESHOLD:
                matching_pairs.append(pair)
            print(f"Domain similarity for {pair[0]} and {pair[1]} is {domain_similarity_avg}")
            print('-'*60)
            break
        

    print(f'\nFor {study}, we have:')
    print('Groundtruth:', groundtruth)
    print('Found pairs', matching_pairs)
    precision, recall, f1_score = calculate_metrics(groundtruth, matching_pairs)
    print(f"Precision: {precision}, Recall: {recall}, F1 Score: {f1_score}")
    scores[study] = (precision, recall, f1_score)

        # ## check remaining of ground truth
        # remaining_pairs = list(set(groundtruth) - set(matching_pairs))
        # print('Remaining pairs:', remaining_pairs)

        # for pair in remaining_pairs:
        #     print('\nChecking similarity values for column:', pair[0], pair[1])
        #     candidate_col_values =  candidate_df[pair[0]].dropna().astype(str).unique()
        #     candidate_col_values = [c.lower() for c in candidate_col_values if c.lower() not in cat_null_values]
            
        #     target_col_values = gdc_df[pair[1]].dropna().astype(str).unique()
        #     target_col_values = [c.lower() for c in target_col_values ]
        #     domain_similarity_avg = check_domains_tf(candidate_col_values, target_col_values)
        #     if domain_similarity_avg > DOMAIN_SIMILARITY_THRESHOLD:
        #         matching_pairs.append(pair)
        #     print(f"Domain similarity for {pair[0]} and {pair[1]} is {domain_similarity_avg}")
        #     print('-'*60)

        # print('\nSo far, we have:')
        # print('Groundtruth:', groundtruth)
        # print('Found pairs', matching_pairs)
        # precision, recall, f1_score = calculate_metrics(groundtruth, matching_pairs)
        # print(f"Precision: {precision}, Recall: {recall}, F1 Score: {f1_score}")
print('\n')
for k,v in scores.items():
    precision, recall, f1_score = v
    print(f'{k}: Precision: {precision}, Recall: {recall}, F1 Score: {f1_score}')
# Out:
# 3
# [('tumor.stage', 'ajcc_pathologic_stage'), ('gender', 'gender'), ('ethnicity', 'ethnicity')]
#
# Processing ../data/extracted-tables/Krug_D)_QC_mutation_calls.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
#                    From          To  Similarity
# 3  tumor_sample_barcode  tumor_code       0.474
#
#
# Checking similarity values for column: tumor_sample_barcode tumor_code
# Domain similarity for tumor_sample_barcode and tumor_code is nan
# ------------------------------------------------------------
#
# Checking similarity values for remaining columns
# [('hugo_symbol', 'tumor_focality'), ('variant_type', 'morphology'), ('variant_classification', 'tumor_grade'), ('tumor_sample_barcode', 'ajcc_pathologic_t'), ('passed_filters', 'primary_diagnosis'), ('matched_norm_sample_barcode', 'tumor_code')]
# Domain similarity for hugo_symbol and tumor_focality is 0.1455
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Krug_A)_Metadata.csv
#
# Exact column name matches between candidate table and gdc ['ethnicity', 'gender']
# Checking similarity values for column: ethnicity
# Domain similarity for ethnicity is 0.738
# ------------------------------------------------------------
# Checking similarity values for column: gender
# Domain similarity for gender is 1.0
# ------------------------------------------------------------
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('top2a.proteogenomic.status', 'tumor_focality'), ('cd3.tils.status', 'morphology'), ('tmt.channel', 'tumor_grade'), ('akt1.mutation.type', 'ajcc_pathologic_t'), ('sample.id', 'primary_diagnosis'), ('tnbc.updated.clinical.status', 'tumor_code'), ('apobec.signature', 'ajcc_pathologic_n'), ('arid1a.mutation.type', 'ajcc_pathologic_stage'), ('cd3.tils.counts', 'vital_status'), ('cbfb.mutation.type', 'race'), ('pten.mutation.type', 'tissue_or_organ_of_origin')]
# Domain similarity for top2a.proteogenomic.status and tumor_focality is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Krug_B)_QC_RNA-seq.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('sample.id', 'tumor_focality'), ('acgt tag id', 'morphology'), ('qc', 'tumor_grade'), ('notes', 'ajcc_pathologic_t')]
# Domain similarity for sample.id and tumor_focality is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Krug_C)_QC_WXS.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('participant', 'tumor_focality'), ('sample_id', 'morphology'), ('type', 'tumor_grade')]
# Domain similarity for participant and tumor_focality is nan
# ------------------------------------------------------------
#
# For Krug, we have:
# Groundtruth: [('tumor.stage', 'ajcc_pathologic_stage'), ('gender', 'gender'), ('ethnicity', 'ethnicity')]
# Found pairs [('ethnicity', 'ethnicity'), ('gender', 'gender')]
# Precision: 1.0, Recall: 0.6666666666666666, F1 Score: 0.8
# 9
# [('gender', 'gender'), ('race', 'race'), ('ethnicity_self_identify', 'ethnicity'), ('tumor_focality', 'tumor_focality'), ('histologic_type', 'primary_diagnosis'), ('grade', 'tumor_grade'), ('tumor_stage_pathological', 'ajcc_pathologic_stage'), ('path_stage_primary_tumor_pt', 'ajcc_pathologic_t'), ('path_stage_reg_lymph_nodes_pn', 'ajcc_pathologic_n')]
#
# Processing ../data/extracted-tables/Clark_data_sample_availability.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('unnamed: 1', 'tumor_focality'), ('unnamed: 2', 'morphology'), ('unnamed: 4', 'tumor_grade'), ('table: sample size of different data sets after excluding samples with low quality.', 'ajcc_pathologic_t'), ('unnamed: 3', 'primary_diagnosis')]
# Domain similarity for unnamed: 1 and tumor_focality is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Clark_RNA-seq_sequencing_depth.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('case', 'tumor_focality'), ('tissue type', 'morphology'), ('sample aliquot id', 'tumor_grade')]
# Domain similarity for case and tumor_focality is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Clark_WGS-WES_sequencing_depth.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('bam file', 'tumor_focality'), ('case', 'morphology'), ('sample aliquot', 'tumor_grade')]
# Domain similarity for bam file and tumor_focality is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Clark_ccrcc_clinical_characteristics.csv
#
# Exact column name matches between candidate table and gdc ['tumor_focality', 'race', 'gender']
# Checking similarity values for column: tumor_focality
# Domain similarity for tumor_focality is 1.0
# ------------------------------------------------------------
# Checking similarity values for column: race
# Domain similarity for race is 1.0
# ------------------------------------------------------------
# Checking similarity values for column: gender
# Domain similarity for gender is 1.0
# ------------------------------------------------------------
#
#
# Similar column name matches between candidate table and gdc
#                         From                     To  Similarity
# 5    ethnicity_self_identify              ethnicity       0.553
# 10                     grade            tumor_grade       0.684
# 11  tumor_stage_pathological  ajcc_pathologic_stage       0.499
#
#
# Checking similarity values for column: ethnicity_self_identify ethnicity
# Domain similarity for ethnicity_self_identify and ethnicity is 0.0705
# ------------------------------------------------------------
# Checking similarity values for column: grade tumor_grade
# Domain similarity for grade and tumor_grade is nan
# ------------------------------------------------------------
# Checking similarity values for column: tumor_stage_pathological ajcc_pathologic_stage
# Domain similarity for tumor_stage_pathological and ajcc_pathologic_stage is 1.0
# ------------------------------------------------------------
#
# Checking similarity values for remaining columns
# [('tumor_site', 'morphology'), ('tumor_site_other', 'tumor_grade'), ('grade', 'ajcc_pathologic_t'), ('ethnicity_self_identify', 'primary_diagnosis'), ('path_stage_primary_tumor_pt', 'tumor_code'), ('path_stage_reg_lymph_nodes_pn', 'ethnicity'), ('case_id', 'ajcc_pathologic_n'), ('tumor/normal', 'vital_status'), ('histologic_type', 'tissue_or_organ_of_origin')]
# Domain similarity for tumor_site and morphology is nan
# ------------------------------------------------------------
#
# For Clark, we have:
# Groundtruth: [('gender', 'gender'), ('race', 'race'), ('ethnicity_self_identify', 'ethnicity'), ('tumor_focality', 'tumor_focality'), ('histologic_type', 'primary_diagnosis'), ('grade', 'tumor_grade'), ('tumor_stage_pathological', 'ajcc_pathologic_stage'), ('path_stage_primary_tumor_pt', 'ajcc_pathologic_t'), ('path_stage_reg_lymph_nodes_pn', 'ajcc_pathologic_n')]
# Found pairs [('tumor_focality', 'tumor_focality'), ('race', 'race'), ('gender', 'gender'), ('tumor_stage_pathological', 'ajcc_pathologic_stage')]
# Precision: 1.0, Recall: 0.4444444444444444, F1 Score: 0.6153846153846153
# 5
# [('gender', 'gender'), ('pt', 'ajcc_pathologic_t'), ('pn', 'ajcc_pathologic_n'), ('stage', 'ajcc_pathologic_stage'), ('vital.status', 'vital_status')]
#
# Processing ../data/extracted-tables/Vasaikar_B-ClinicalData.csv
#
# Exact column name matches between candidate table and gdc ['gender']
# Checking similarity values for column: gender
# Domain similarity for gender is 1.0
# ------------------------------------------------------------
#
#
# Similar column name matches between candidate table and gdc
#      From                     To  Similarity
# 17  stage  ajcc_pathologic_stage       0.408
#
#
# Checking similarity values for column: stage ajcc_pathologic_stage
# Domain similarity for stage and ajcc_pathologic_stage is 1.0
# ------------------------------------------------------------
#
# Checking similarity values for remaining columns
# [('pt', 'tumor_focality'), ('cea', 'morphology'), ('mirna-seq', 'tumor_grade'), ('msi_pcr_result', 'ajcc_pathologic_t'), ('polyps_history', 'primary_diagnosis'), ('pole_mutation', 'tumor_code'), ('msh2_mutation', 'ajcc_pathologic_n'), ('mrna-seq', 'ethnicity'), ('pros', 'vital_status'), ('age', 'race'), ('immunescore', 'tissue_or_organ_of_origin')]
# Domain similarity for pt and tumor_focality is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Vasaikar_A-Annotation.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('data type', 'tumor_focality'), ('column definition', 'morphology'), ('column name', 'tumor_grade'), ('definition', 'ajcc_pathologic_t')]
# Domain similarity for data type and tumor_focality is nan
# ------------------------------------------------------------
#
# For Vasaikar, we have:
# Groundtruth: [('gender', 'gender'), ('pt', 'ajcc_pathologic_t'), ('pn', 'ajcc_pathologic_n'), ('stage', 'ajcc_pathologic_stage'), ('vital.status', 'vital_status')]
# Found pairs [('gender', 'gender'), ('stage', 'ajcc_pathologic_stage')]
# Precision: 1.0, Recall: 0.4, F1 Score: 0.5714285714285715
# 3
# [('gender', 'gender'), ('ethnicity', 'ethnicity'), ('dominant.histological.subtype', 'primary_diagnosis')]
#
# Processing ../data/extracted-tables/Gillette_Annotions_S1A.csv
#
# Exact column name matches between candidate table and gdc ['ethnicity', 'gender']
# Checking similarity values for column: ethnicity
# Domain similarity for ethnicity is 0.729
# ------------------------------------------------------------
# Checking similarity values for column: gender
# Domain similarity for gender is 1.0
# ------------------------------------------------------------
#
#
# Similar column name matches between candidate table and gdc
#     From                     To  Similarity
# 6  stage  ajcc_pathologic_stage       0.426
#
#
# Checking similarity values for column: stage ajcc_pathologic_stage
# Domain similarity for stage and ajcc_pathologic_stage is nan
# ------------------------------------------------------------
#
# Checking similarity values for remaining columns
# [('keap1.mutation', 'tumor_focality'), ('methylation.qc', 'morphology'), ('qc.status', 'tumor_grade'), ('smoking.history', 'ajcc_pathologic_t'), ('dominant.signature.wgs.notsmoking.50perc', 'primary_diagnosis'), ('cimp.status', 'tumor_code'), ('kras.mutation', 'ajcc_pathologic_n'), ('aliquot', 'ajcc_pathologic_stage'), ('sample.id', 'vital_status'), ('dominant.histological.subtype', 'race'), ('erbb2.mutation', 'tissue_or_organ_of_origin')]
# Domain similarity for keap1.mutation and tumor_focality is nan
# ------------------------------------------------------------
#
# For Gillette, we have:
# Groundtruth: [('gender', 'gender'), ('ethnicity', 'ethnicity'), ('dominant.histological.subtype', 'primary_diagnosis')]
# Found pairs [('ethnicity', 'ethnicity'), ('gender', 'gender')]
# Precision: 1.0, Recall: 0.6666666666666666, F1 Score: 0.8
# 4
# [('gender', 'gender'), ('race', 'race'), ('ethnicity', 'ethnicity'), ('vital_status', 'vital_status')]
#
# Processing ../data/extracted-tables/Wang_additional_annotations.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('tp53_alter_status', 'tumor_focality'), ('pdgfra_alter_status', 'morphology'), ('nf1_alter_status', 'tumor_grade'), ('atrx_alter_status', 'ajcc_pathologic_t'), ('telomere', 'primary_diagnosis'), ('mirna', 'tumor_code'), ('ancestry_prediction', 'gender'), ('nmf_consensus', 'ajcc_pathologic_n'), ('multiomic', 'ethnicity'), ('tert_alter_status', 'ajcc_pathologic_stage'), ('braf_alter_status', 'vital_status'), ('dna_methyl_mnp', 'race'), ('case', 'tissue_or_organ_of_origin')]
# Domain similarity for tp53_alter_status and tumor_focality is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Wang_survival_analysis.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('stratification group', 'tumor_focality'), ('group value', 'morphology')]
# Domain similarity for stratification group and tumor_focality is 0.338
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Wang_cbttc_sample_info.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('aliquot_id', 'tumor_focality'), ('kids_first_id', 'morphology'), ('research_id', 'tumor_grade'), ('clinical_status_at_collection_event', 'ajcc_pathologic_t'), ('sample_id', 'primary_diagnosis'), ('original_aliquot_id', 'tumor_code'), ('tmt_channel', 'gender')]
# Domain similarity for aliquot_id and tumor_focality is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Wang_clinical_data.csv
#
# Exact column name matches between candidate table and gdc ['ethnicity', 'vital_status', 'race', 'gender']
# Checking similarity values for column: ethnicity
# Domain similarity for ethnicity is 1.0
# ------------------------------------------------------------
# Checking similarity values for column: vital_status
# Domain similarity for vital_status is 0.202
# ------------------------------------------------------------
# Checking similarity values for column: race
# Domain similarity for race is 1.0
# ------------------------------------------------------------
# Checking similarity values for column: gender
# Domain similarity for gender is 1.0
# ------------------------------------------------------------
#
#
# Similar column name matches between candidate table and gdc
#                       From         To  Similarity
# 5  ethnicity_self_identify  ethnicity       0.523
#
#
# Checking similarity values for column: ethnicity_self_identify ethnicity
# Domain similarity for ethnicity_self_identify and ethnicity is 0.058
# ------------------------------------------------------------
#
# Checking similarity values for remaining columns
# [('exclusion_reason', 'tumor_focality'), ('cause_of_death', 'morphology'), ('tumor_laterality', 'tumor_grade'), ('lost_to_follow_up', 'ajcc_pathologic_t'), ('expert_path_review_details', 'primary_diagnosis'), ('smoking_history', 'tumor_code'), ('vital_status', 'ajcc_pathologic_stage'), ('tumor_site_curation_notes', 'ajcc_pathologic_n'), ('country_of_origin', 'vital_status'), ('ethnicity_self_identify', 'tissue_or_organ_of_origin')]
# Domain similarity for exclusion_reason and tumor_focality is nan
# ------------------------------------------------------------
#
# For Wang, we have:
# Groundtruth: [('gender', 'gender'), ('race', 'race'), ('ethnicity', 'ethnicity'), ('vital_status', 'vital_status')]
# Found pairs [('ethnicity', 'ethnicity'), ('race', 'race'), ('gender', 'gender')]
# Precision: 1.0, Recall: 0.75, F1 Score: 0.8571428571428571
# 3
# [('stage', 'ajcc_pathologic_stage'), ('gender', 'gender'), ('ethnicity', 'ethnicity')]
#
# Processing ../data/extracted-tables/Satpathy_Table_S1A.csv
#
# Exact column name matches between candidate table and gdc ['ethnicity', 'gender']
# Checking similarity values for column: ethnicity
# Domain similarity for ethnicity is 0.124
# ------------------------------------------------------------
# Checking similarity values for column: gender
# Domain similarity for gender is 1.0
# ------------------------------------------------------------
#
#
# Similar column name matches between candidate table and gdc
#              From                     To  Similarity
# 6           stage  ajcc_pathologic_stage       0.412
# 11  ethnicity_mod              ethnicity       0.805
# 16      qc.status           vital_status       0.403
#
#
# Checking similarity values for column: stage ajcc_pathologic_stage
# Domain similarity for stage and ajcc_pathologic_stage is 0.828
# ------------------------------------------------------------
# Checking similarity values for column: ethnicity_mod ethnicity
# Domain similarity for ethnicity_mod and ethnicity is nan
# ------------------------------------------------------------
# Checking similarity values for column: qc.status vital_status
# Domain similarity for qc.status and vital_status is nan
# ------------------------------------------------------------
#
# Checking similarity values for remaining columns
# [('tcga pan-can immune clustering', 'tumor_focality'), ('pten.mutation', 'morphology'), ('sample.id', 'tumor_grade'), ('pathology.based.histology.assessment', 'ajcc_pathologic_t'), ('cdkn2a.mutation', 'primary_diagnosis'), ('secondhand.smoke', 'tumor_code'), ('participant', 'ajcc_pathologic_n'), ('tp53.mutation', 'ethnicity'), ('nmf.subtype.core', 'vital_status'), ('type', 'race'), ('immunecluster.rna', 'tissue_or_organ_of_origin')]
# Domain similarity for tcga pan-can immune clustering and tumor_focality is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Satpathy_Table_S1C.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('unnamed: 5', 'tumor_focality'), ('unnamed: 7', 'morphology'), ('unnamed: 1', 'tumor_grade'), ('unnamed: 11', 'ajcc_pathologic_t'), ('unnamed: 8', 'primary_diagnosis'), ('unnamed: 4', 'tumor_code'), ('unnamed: 3', 'ajcc_pathologic_n'), ('nmf cluster (p<0.05)', 'ethnicity'), ('unnamed: 10', 'vital_status'), ('unnamed: 9', 'race'), ('unnamed: 6', 'tissue_or_organ_of_origin')]
# Domain similarity for unnamed: 5 and tumor_focality is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Satpathy_Table_S1E.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('unnamed: 5', 'tumor_focality'), ('unnamed: 7', 'morphology'), ('unnamed: 1', 'tumor_grade'), ('unnamed: 8', 'ajcc_pathologic_t'), ('counts', 'primary_diagnosis'), ('unnamed: 0', 'tumor_code'), ('unnamed: 4', 'ajcc_pathologic_n'), ('unnamed: 3', 'ethnicity'), ('p-values (bonferroni corrected)', 'vital_status'), ('unnamed: 9', 'race')]
# Domain similarity for unnamed: 5 and tumor_focality is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Satpathy_Table_S1D.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('unnamed: 5', 'tumor_focality'), ('unnamed: 1', 'morphology'), ('unnamed: 11', 'tumor_grade'), ('unnamed: 8', 'ajcc_pathologic_t'), ('counts', 'primary_diagnosis'), ('unnamed: 0', 'tumor_code'), ('unnamed: 4', 'ajcc_pathologic_n'), ('unnamed: 3', 'ethnicity'), ('p-values (bonferroni corrected)', 'vital_status'), ('unnamed: 10', 'race'), ('unnamed: 6', 'tissue_or_organ_of_origin')]
# Domain similarity for unnamed: 5 and tumor_focality is nan
# ------------------------------------------------------------
#
# For Satpathy, we have:
# Groundtruth: [('stage', 'ajcc_pathologic_stage'), ('gender', 'gender'), ('ethnicity', 'ethnicity')]
# Found pairs [('gender', 'gender'), ('stage', 'ajcc_pathologic_stage')]
# Precision: 1.0, Recall: 0.6666666666666666, F1 Score: 0.8
# 7
# [('sex', 'gender'), ('race', 'race'), ('tumor_focality', 'tumor_focality'), ('pathologic_staging_regional_lymph_nodes_pn', 'ajcc_pathologic_n'), ('pathologic_staging_primary_tumor_pt', 'ajcc_pathologic_t'), ('tumor_stage_pathological', 'ajcc_pathologic_stage'), ('vital_status', 'vital_status')]
#
# Processing ../data/extracted-tables/Cao_circRNAForNAT.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('unnamed: 0', 'tumor_focality')]
# Domain similarity for unnamed: 0 and tumor_focality is 0.0765
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Cao_Clinical_data.csv
#
# Exact column name matches between candidate table and gdc ['tumor_focality', 'vital_status', 'race']
# Checking similarity values for column: tumor_focality
# Domain similarity for tumor_focality is 1.0
# ------------------------------------------------------------
# Checking similarity values for column: vital_status
# Domain similarity for vital_status is 0.202
# ------------------------------------------------------------
# Checking similarity values for column: race
# Domain similarity for race is 1.0
# ------------------------------------------------------------
#
#
# Similar column name matches between candidate table and gdc
#                                         From                     To  \
# 3                        histology_diagnosis      primary_diagnosis
# 14       pathologic_staging_primary_tumor_pt  ajcc_pathologic_stage
# 15  pathologic_staging_distant_metastasis_pm  ajcc_pathologic_stage
# 18                  tumor_stage_pathological  ajcc_pathologic_stage
#
#     Similarity
# 3        0.535
# 14       0.414
# 15       0.406
# 18       0.488
#
#
# Checking similarity values for column: histology_diagnosis primary_diagnosis
# Domain similarity for histology_diagnosis and primary_diagnosis is 1.0
# ------------------------------------------------------------
# Checking similarity values for column: pathologic_staging_primary_tumor_pt ajcc_pathologic_stage
# Domain similarity for pathologic_staging_primary_tumor_pt and ajcc_pathologic_stage is nan
# ------------------------------------------------------------
# Checking similarity values for column: pathologic_staging_distant_metastasis_pm ajcc_pathologic_stage
# Domain similarity for pathologic_staging_distant_metastasis_pm and ajcc_pathologic_stage is nan
# ------------------------------------------------------------
# Checking similarity values for column: tumor_stage_pathological ajcc_pathologic_stage
# Domain similarity for tumor_stage_pathological and ajcc_pathologic_stage is 1.0
# ------------------------------------------------------------
#
# Checking similarity values for remaining columns
# [('clinical_staging_distant_metastasis_cm', 'morphology'), ('cause_of_death', 'tumor_grade'), ('tumor_included_for_the_study', 'ajcc_pathologic_t'), ('stromal_fraction', 'tumor_code'), ('tumor_necrosis', 'gender'), ('is_this_patient_lost_to_follow_up', 'ethnicity'), ('pathologic_staging_primary_tumor_pt', 'ajcc_pathologic_n'), ('muscle_fraction', 'vital_status'), ('residual_tumor', 'tissue_or_organ_of_origin')]
# Domain similarity for clinical_staging_distant_metastasis_cm and morphology is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Cao_TMT_labeling_scheme.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('channel_name', 'morphology'), ('sample_type', 'tumor_grade'), ('case_id', 'ajcc_pathologic_t')]
# Domain similarity for channel_name and morphology is 0.383
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Cao_Molecular_phenotype_data.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
#          From            To  Similarity
# 4  msi_status  vital_status       0.435
#
#
# Checking similarity values for column: msi_status vital_status
# Domain similarity for msi_status and vital_status is nan
# ------------------------------------------------------------
#
# Checking similarity values for remaining columns
# [('bailey', 'morphology'), ('collisson', 'tumor_grade'), ('moffitt', 'ajcc_pathologic_t'), ('case_id', 'tumor_code'), ('msi_status', 'gender')]
# Domain similarity for bailey and morphology is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Cao_circRNAforTumor.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('unnamed: 0', 'morphology')]
# Domain similarity for unnamed: 0 and morphology is 0.261
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Cao_Proteins_phospho_glyco_IDs.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('case_id', 'morphology'), ('type', 'tumor_grade'), ('tmt_channel', 'ajcc_pathologic_t')]
# Domain similarity for case_id and morphology is 0.321
# ------------------------------------------------------------
#
# For Cao, we have:
# Groundtruth: [('sex', 'gender'), ('race', 'race'), ('tumor_focality', 'tumor_focality'), ('pathologic_staging_regional_lymph_nodes_pn', 'ajcc_pathologic_n'), ('pathologic_staging_primary_tumor_pt', 'ajcc_pathologic_t'), ('tumor_stage_pathological', 'ajcc_pathologic_stage'), ('vital_status', 'vital_status')]
# Found pairs [('tumor_focality', 'tumor_focality'), ('race', 'race'), ('histology_diagnosis', 'primary_diagnosis'), ('tumor_stage_pathological', 'ajcc_pathologic_stage')]
# Precision: 0.75, Recall: 0.42857142857142855, F1 Score: 0.5454545454545454
# 7
# [('gender', 'gender'), ('tumor_focality', 'tumor_focality'), ('histologic_type', 'primary_diagnosis'), ('histologic_grade', 'tumor_grade'), ('patho_staging_pt', 'ajcc_pathologic_t'), ('patho_staging_pn', 'ajcc_pathologic_n'), ('tumor_stage', 'ajcc_pathologic_stage')]
#
# Processing ../data/extracted-tables/Huang_Meta_table.csv
#
# Exact column name matches between candidate table and gdc ['tumor_focality', 'gender']
# Checking similarity values for column: tumor_focality
# Domain similarity for tumor_focality is 1.0
# ------------------------------------------------------------
# Checking similarity values for column: gender
# Domain similarity for gender is 1.0
# ------------------------------------------------------------
#
#
# Similar column name matches between candidate table and gdc
#                       From          To  Similarity
# 24  tumor_pathology_review  morphology        0.41
#
#
# Checking similarity values for column: tumor_pathology_review morphology
# Domain similarity for tumor_pathology_review and morphology is 0.251
# ------------------------------------------------------------
#
# Checking similarity values for remaining columns
# [('smoke_age_stop', 'morphology'), ('patho_staging_pn', 'tumor_grade'), ('smoking_inferred', 'ajcc_pathologic_t'), ('tumor_site_original', 'primary_diagnosis'), ('patho_staging_pt', 'tumor_code'), ('smoking_history', 'ajcc_pathologic_n'), ('tumor_necrosis', 'ethnicity'), ('integrated_subtype', 'ajcc_pathologic_stage'), ('histologic_type', 'vital_status'), ('tumor_stage', 'race'), ('country', 'tissue_or_organ_of_origin')]
# Domain similarity for smoke_age_stop and morphology is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Huang_Data_availabilty.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('1: available; 0: unavailable', 'morphology'), ('case_id', 'tumor_grade')]
# Domain similarity for 1: available; 0: unavailable and morphology is nan
# ------------------------------------------------------------
#
# Processing ../data/extracted-tables/Huang_TMT-set.csv
#
# Exact column name matches between candidate table and gdc []
#
#
# Similar column name matches between candidate table and gdc
# Empty DataFrame
# Columns: [From, To, Similarity]
# Index: []
#
#
#
# Checking similarity values for remaining columns
# [('channel #', 'morphology'), ('case_id', 'tumor_grade'), ('combined_id', 'ajcc_pathologic_t'), ('type', 'primary_diagnosis')]
# Domain similarity for channel # and morphology is 0.383
# ------------------------------------------------------------
#
# For Huang, we have:
# Groundtruth: [('gender', 'gender'), ('tumor_focality', 'tumor_focality'), ('histologic_type', 'primary_diagnosis'), ('histologic_grade', 'tumor_grade'), ('patho_staging_pt', 'ajcc_pathologic_t'), ('patho_staging_pn', 'ajcc_pathologic_n'), ('tumor_stage', 'ajcc_pathologic_stage')]
# Found pairs [('tumor_focality', 'tumor_focality'), ('gender', 'gender')]
# Precision: 1.0, Recall: 0.2857142857142857, F1 Score: 0.4444444444444445
# 10
# [('histologic_grade_figo', 'tumor_grade'), ('histologic_type', 'primary_diagnosis'), ('path_stage_primary_tumor-pt', 'ajcc_pathologic_t'), ('path_stage_reg_lymph_nodes-pn', 'ajcc_pathologic_n'), ('tumor_stage-pathological', 'ajcc_pathologic_stage'), ('race', 'race'), ('ethnicity', 'ethnicity'), ('gender', 'gender'), ('tumor_site', 'tissue_or_organ_of_origin'), ('tumor_focality', 'tumor_focality')]
#
# Processing ../data/extracted-tables/Dou_UCEC_CPTAC3_meta_table_V2.1.csv
#
# Exact column name matches between candidate table and gdc ['tumor_focality', 'race', 'ethnicity', 'gender']
# Checking similarity values for column: tumor_focality
# Domain similarity for tumor_focality is 1.0
# ------------------------------------------------------------
# Checking similarity values for column: race
# Domain similarity for race is 1.0
# ------------------------------------------------------------
# Checking similarity values for column: ethnicity
# Domain similarity for ethnicity is 0.8955
# ------------------------------------------------------------
# Checking similarity values for column: gender
# Domain similarity for gender is 1.0
# ------------------------------------------------------------
#
#
# Similar column name matches between candidate table and gdc
#                         From                     To  Similarity
# 18  tumor_stage-pathological  ajcc_pathologic_stage       0.531
# 38                msi_status           vital_status       0.456
#
#
# Checking similarity values for column: tumor_stage-pathological ajcc_pathologic_stage
# Domain similarity for tumor_stage-pathological and ajcc_pathologic_stage is 1.0
# ------------------------------------------------------------
# Checking similarity values for column: msi_status vital_status
# Domain similarity for msi_status and vital_status is nan
# ------------------------------------------------------------
#
# Checking similarity values for remaining columns
# [('case_excluded', 'morphology'), ('myometrial_invasion_specify', 'tumor_grade'), ('wxs_tumor_sample_type', 'ajcc_pathologic_t'), ('wgs_normal_uuid', 'primary_diagnosis'), ('wxs_normal_uuid', 'tumor_code'), ('rnaseq_r2_sample_type', 'ajcc_pathologic_n'), ('p53', 'vital_status'), ('proteomics_oct', 'tissue_or_organ_of_origin')]
# Domain similarity for case_excluded and morphology is nan
# ------------------------------------------------------------
#
# For Dou, we have:
# Groundtruth: [('histologic_grade_figo', 'tumor_grade'), ('histologic_type', 'primary_diagnosis'), ('path_stage_primary_tumor-pt', 'ajcc_pathologic_t'), ('path_stage_reg_lymph_nodes-pn', 'ajcc_pathologic_n'), ('tumor_stage-pathological', 'ajcc_pathologic_stage'), ('race', 'race'), ('ethnicity', 'ethnicity'), ('gender', 'gender'), ('tumor_site', 'tissue_or_organ_of_origin'), ('tumor_focality', 'tumor_focality')]
# Found pairs [('tumor_focality', 'tumor_focality'), ('race', 'race'), ('ethnicity', 'ethnicity'), ('gender', 'gender'), ('tumor_stage-pathological', 'ajcc_pathologic_stage')]
# Precision: 1.0, Recall: 0.5, F1 Score: 0.6666666666666666
#
#
# Krug: Precision: 1.0, Recall: 0.6666666666666666, F1 Score: 0.8
# Clark: Precision: 1.0, Recall: 0.4444444444444444, F1 Score: 0.6153846153846153
# Vasaikar: Precision: 1.0, Recall: 0.4, F1 Score: 0.5714285714285715
# Gillette: Precision: 1.0, Recall: 0.6666666666666666, F1 Score: 0.8
# Wang: Precision: 1.0, Recall: 0.75, F1 Score: 0.8571428571428571
# Satpathy: Precision: 1.0, Recall: 0.6666666666666666, F1 Score: 0.8
# Cao: Precision: 0.75, Recall: 0.42857142857142855, F1 Score: 0.5454545454545454
# Huang: Precision: 1.0, Recall: 0.2857142857142857, F1 Score: 0.4444444444444445
# Dou: Precision: 1.0, Recall: 0.5, F1 Score: 0.6666666666666666
