# %%
import json
import pandas as pd
result_path = '../table-union/results-cl/top_20_results.json'



with open(result_path) as f:
    results = json.load(f)
    df = pd.DataFrame(results)

df
# Out:
#     Table name Candidate column               Ground truth column  \
# 0         Krug      Tumor.Stage             ajcc_pathologic_stage
# 1         Krug     Age.in.Month                  age_at_diagnosis
# 2         Krug           Gender                            gender
# 3         Krug        Ethnicity                         ethnicity
# 4        Clark     Tumor/Normal                       tissue_type
# ..         ...              ...                               ...
# 121        Dou        Ethnicity                         ethnicity
# 122        Dou           Gender                            gender
# 123        Dou       Tumor_Site         tissue_or_organ_of_origin
# 124        Dou   Tumor_Focality                    tumor_focality
# 125        Dou    Tumor_Size_cm  tumor_largest_dimension_diameter
#
#                                          Top k columns
# 0    [figo_stage, uicc_clinical_stage, ajcc_patholo...
# 1    [age_at_diagnosis, age_at_index, relationship_...
# 2    [gender, relationship_gender, pregnant_at_diag...
# 3    [race, ethnicity, eye_color, country_of_reside...
# 4    [tissue_type, non_nodal_tumor_deposits, select...
# ..                                                 ...
# 121  [race, ethnicity, variant_origin, country_of_b...
# 122  [gender, relationship_gender, inpc_histologic_...
# 123  [margins_involved_site, supratentorial_localiz...
# 124  [tumor_focality, non_nodal_tumor_deposits, tum...
# 125  [tumor_depth_measurement, shortest_dimension, ...
#
# [126 rows x 4 columns]

# %%
gdc_path = '../table-union/data/gdc_schema_extracted.csv'
gdc_df = pd.read_csv(gdc_path)
gdc_cols = gdc_df['column name'].unique()

# %%
df = df[~df['Candidate column'].str.lower().isin(gdc_cols)]
df
# Out:
#     Table name          Candidate column               Ground truth column  \
# 0         Krug               Tumor.Stage             ajcc_pathologic_stage
# 1         Krug              Age.in.Month                  age_at_diagnosis
# 4        Clark              Tumor/Normal                       tissue_type
# 6        Clark                       Age                  age_at_diagnosis
# 9        Clark   Ethnicity_Self_Identify                         ethnicity
# ..         ...                       ...                               ...
# 115        Dou   Path_Stage_Dist_Mets-pM                 ajcc_pathologic_m
# 116        Dou  tumor_Stage-Pathological             ajcc_pathologic_stage
# 119        Dou                       Age                  age_at_diagnosis
# 123        Dou                Tumor_Site         tissue_or_organ_of_origin
# 125        Dou             Tumor_Size_cm  tumor_largest_dimension_diameter
#
#                                          Top k columns
# 0    [figo_stage, uicc_clinical_stage, ajcc_patholo...
# 1    [age_at_diagnosis, age_at_index, relationship_...
# 4    [tissue_type, non_nodal_tumor_deposits, select...
# 6    [age_at_onset, age_at_index, relationship_age_...
# 9    [race, ethnicity, demographics, country_of_bir...
# ..                                                 ...
# 115  [ajcc_clinical_m, ajcc_pathologic_m, uicc_clin...
# 116  [ensat_pathologic_stage, inss_stage, iss_stage...
# 119  [age_at_index, relationship_age_at_diagnosis, ...
# 123  [margins_involved_site, supratentorial_localiz...
# 125  [tumor_depth_measurement, shortest_dimension, ...
#
# [90 rows x 4 columns]

# %%
interested_columns  = set()
interested_columns.update(df['Ground truth column'].unique()) 



interested_columns.update([item for sublist in df['Top k columns'] for item in sublist])
len(interested_columns)
# Out:
# 454

# %%
filtered_gdc_df = gdc_df[gdc_df['column name'].isin(interested_columns)]
filtered_gdc_df

filtered_gdc_df
# Out:
#                        column name    column type  \
# 1                        aa_change         string
# 4                 adapter_sequence         string
# 5    additional_pathology_findings  Not specified
# 8              adverse_event_grade  Not specified
# 9                 age_at_diagnosis         number
# ..                             ...            ...
# 725                  workflow_link         string
# 729                  year_of_birth  Not specified
# 730                  year_of_death        integer
# 733                   years_smoked         number
# 734        zone_of_origin_prostate  Not specified
#
#                                          column values
# 1                                        Not specified
# 4                                        Not specified
# 5    Asbestos bodies, Bilateral ovaries with endome...
# 8          Grade 1, Grade 2, Grade 3, Grade 4, Grade 5
# 9                                        Not specified
# ..                                                 ...
# 725                                      Not specified
# 729                                      Not specified
# 730                                      Not specified
# 733                                      Not specified
# 734  Central zone, Overlapping/multiple zones, Peri...
#
# [454 rows x 3 columns]

# %%
specified_values_gdc = filtered_gdc_df[filtered_gdc_df['column values'] != 'Not specified']
non_specified_values_gdc = filtered_gdc_df[filtered_gdc_df['column values'] == 'Not specified']

print(len(specified_values_gdc))
print(len(non_specified_values_gdc))
total_len = len(specified_values_gdc) + len(non_specified_values_gdc)
print(total_len)
# Out:
# 248
# 206
# 454

# %%
specified_values_gdc
# Out:
#                         column name    column type  \
# 5     additional_pathology_findings  Not specified
# 8               adverse_event_grade  Not specified
# 16                  ajcc_clinical_m  Not specified
# 17                  ajcc_clinical_n  Not specified
# 18              ajcc_clinical_stage  Not specified
# ..                              ...            ...
# 720                    wgs_coverage  Not specified
# 721                   who_cns_grade  Not specified
# 722                   who_nte_grade  Not specified
# 723  wilms_tumor_histologic_subtype  Not specified
# 734         zone_of_origin_prostate  Not specified
#
#                                          column values
# 5    Asbestos bodies, Bilateral ovaries with endome...
# 8          Grade 1, Grade 2, Grade 3, Grade 4, Grade 5
# 16   M0, M1, M1a, M1b, M1c, MX, Not Allowed To Coll...
# 17   N0 (i+), N0 (mol-), N1, N1a, N1b, N1bI, N1bIV,...
# 18   Stage 0, Stage IA2, Stage IB2, Stage IIA, Stag...
# ..                                                 ...
# 720  0x-10x, 10x-25x, 150x+, 25x-150x, Not Applicab...
# 721  Grade I, Grade II, Grade III, Grade IV, Grade ...
# 722              G1, G2, G3, GX, Not Reported, Unknown
# 723      Favorable, Not Reported, Unfavorable, Unknown
# 734  Central zone, Overlapping/multiple zones, Peri...
#
# [248 rows x 3 columns]

# %%
non_specified_values_gdc
# Out:
#                    column name    column type  column values
# 1                    aa_change         string  Not specified
# 4             adapter_sequence         string  Not specified
# 9             age_at_diagnosis         number  Not specified
# 10                age_at_index  Not specified  Not specified
# 11        age_at_last_exposure        integer  Not specified
# ..                         ...            ...            ...
# 717  weiss_assessment_findings          array  Not specified
# 725              workflow_link         string  Not specified
# 729              year_of_birth  Not specified  Not specified
# 730              year_of_death        integer  Not specified
# 733               years_smoked         number  Not specified
#
# [206 rows x 3 columns]
